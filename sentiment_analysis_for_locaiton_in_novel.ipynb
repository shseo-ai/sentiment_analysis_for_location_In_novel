# %% [markdown]
# ## 1. Importing Library

# %%
import multiprocessing

from gensim.models import Word2Vec
from gensim.models.phrases import Phrases, Phraser

import re  # For preprocessing
import pandas as pd  # For data handling
from time import time  # To time our operations
from collections import defaultdict  # For word frequency

import spacy  # For preprocessing
# !python -m spacy download en
# !python -m spacy download en_core_web_sm

import logging  # Setting up the loggings to monitor gensim
logging.basicConfig(format="%(levelname)s - %(asctime)s: %(message)s", datefmt= '%H:%M:%S', level=logging.INFO)


# visualization
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
 
import seaborn as sns
sns.set_style("darkgrid")

from sklearn.decomposition import PCA
from sklearn.manifold import TSNE

import nltk
# nltk.download('wordnet')
# nltk.download('sentiwordnet')
from nltk.corpus import sentiwordnet as swn

# %% [markdown]
# ## 2. Loading Text File

# %%
file_path = 'A_TALE_OF_TWO_CITIES.txt'

text_data = []
with open(file_path) as f:
    while True:
        line = f.readline()
        if line == '\n': # delete new line mark
            continue
        line = line.replace('\n', '') # delete new line mark in end of each sentence
        if not line:
            break
        text_data.append(line)

print(text_data[:5])
# Out:
# ['A TALE OF TWO CITIES', 'A STORY OF THE FRENCH REVOLUTION', 'By Charles Dickens', 'Book the First—Recalled to Life', 'CHAPTER I.']

# %% [markdown]
# ## 3. Checking Text Data Frame

# %%
text_df = pd.DataFrame(text_data)
text_df.columns = ['sentence']
print("\n")
print("#"*60)
print("head of text data frame")
print(text_df.head(10))
print(text_df.tail(10))
# Out:
# ############################################################
# head of text data frame
#                                             sentence
# 0                               A TALE OF TWO CITIES
# 1                   A STORY OF THE FRENCH REVOLUTION
# 2                                 By Charles Dickens
# 3                    Book the First—Recalled to Life
# 4                                         CHAPTER I.
# 5                                         The Period
# 6  It was the best of times, it was the worst of ...
# 7  There were a king with a large jaw and a queen...
# 8  It was the year of Our Lord one thousand seven...
# 9  France, less favoured on the whole as to matte...
#                                                sentence
# 3373  She kisses his lips; he kisses hers; they sole...
# 3374  “I am the Resurrection and the Life, saith the...
# 3375  The murmuring of many voices, the upturning of...
# 3376  They said of him, about the city that night, t...
# 3377  One of the most remarkable sufferers by the sa...
# 3378  “I see Barsad, and Cly, Defarge, The Vengeance...
# 3379  “I see the lives for which I lay down my life,...
# 3380  “I see that I hold a sanctuary in their hearts...
# 3381  “I see that child who lay upon her bosom and w...
# 3382  “It is a far, far better thing that I do, than...

# %% [markdown]
# ## 4. Preprocessing Text Data

# %%
t = time()
print("\n")
print("#"*60)

print("loading spacy preprocessor...")

nlp = spacy.load('en_core_web_sm', disable=['ner', 'parser']) # disabling Named Entity Recognition for speed
# nlp = spacy.load("en_core_web_sm")

def cleaning(doc):
    # Lemmatizes and removes stopwords
    # doc needs to be a spacy Doc object
    txt = [token.lemma_ for token in doc if not token.is_stop]
    
    # Word2Vec uses context words to learn the vector representation of a target word,
    # if a sentence is only one or two words long,
    # the benefit for the training is very small
    if len(txt) > 2:
        return ' '.join(txt)


print("lower, remove special token...")
brief_cleaning = (re.sub("[^A-Za-z']+", ' ', str(row)).lower() for row in text_df['sentence'])

print("lemmatizing, removing stopwords, removing short sentence...")
txt = [cleaning(text_df) for text_df in nlp.pipe(brief_cleaning, batch_size=5000)]


text_df_clean = pd.DataFrame({'preprocessed_sentence': txt})
print("drop NA, drop duplicates...")
text_df_clean = text_df_clean.dropna().drop_duplicates()
print()
print(text_df_clean.shape)
print(text_df_clean.head(10))
print()


print()
print('Using Gensim Phrases package to automatically detect common phrases (bigrams) from a list of sentences...')
sentences = [row.split() for row in text_df_clean['preprocessed_sentence']]
bigram_model = Phrases(sentences, min_count=30, progress_per=10000)

print("example of bigram vocab")
list(bigram_model.vocab.keys())[:5]

print("change senteces using bigram...")
for i, sentence in enumerate(sentences):
    bigram_s = bigram_model[sentence]
    if sentence != bigram_s:
        sentences[i] = bigram_s
        #print(f'{i}\t', "--"*20)
        #print(f"raw    sentences: {sentence}")
        #print(f"Bigram sentences: {bigram_s}")
print()
print("example of preprocesed sentences")
for i in range(5):
    print(f"sentence {i}: \t", sentences[i])
print()


# word frequency check
"""
word_freq = defaultdict(int)
for sent in sentences:
    for i in sent:
        word_freq[i] += 1
print(len(word_freq))
sorted(word_freq, key=word_freq.get, reverse=True)[:10]
"""

print('Time to clean up everything: {} mins'.format(round((time() - t) / 60, 2)))
# Out:
# ############################################################
# loading spacy preprocessor...
# lower, remove special token...
# lemmatizing, removing stopwords, removing short sentence...
# INFO - 18:45:11: collecting all words and their counts
# INFO - 18:45:11: PROGRESS: at sentence #0, processed 0 words and 0 word types
# INFO - 18:45:11: collected 51724 word types from a corpus of 56457 words (unigram + bigrams) and 2946 sentences
# INFO - 18:45:11: using 51724 counts as vocab in Phrases<0 vocab, min_count=30, threshold=10.0, max_vocab_size=40000000>
# drop NA, drop duplicates...
#
# (2946, 1)
#                                 preprocessed_sentence
# 1                             story french revolution
# 3                                    book recall life
# 6   good time bad time age wisdom age foolishness ...
# 7   king large jaw queen plain face throne england...
# 8   year lord thousand seven seventy spiritual rev...
# 9   france favour matter spiritual sister shield t...
# 10  england scarcely order protection justify nati...
# 11  thing thousand like come pass close dear old y...
# 14  dover road lie friday night late november pers...
# 15  droop head tremulous tail mash way thick mud f...
#
#
# Using Gensim Phrases package to automatically detect common phrases (bigrams) from a list of sentences...
# example of bigram vocab
# change senteces using bigram...
#
# example of preprocesed sentences
# sentence 0: 	 ['story', 'french', 'revolution']
# sentence 1: 	 ['book', 'recall', 'life']
# sentence 2: 	 ['good', 'time', 'bad', 'time', 'age', 'wisdom', 'age', 'foolishness', 'epoch', 'belief', 'epoch', 'incredulity', 'season', 'light', 'season', 'darkness', 'spring', 'hope', 'winter', 'despair', 'go', 'direct', 'heaven', 'go', 'direct', 'way', 'short', 'period', 'far', 'like', 'present', 'period', 'noisy', 'authority', 'insist', 'receive', 'good', 'evil', 'superlative', 'degree', 'comparison']
# sentence 3: 	 ['king', 'large', 'jaw', 'queen', 'plain', 'face', 'throne', 'england', 'king', 'large', 'jaw', 'queen', 'fair', 'face', 'throne', 'france', 'country', 'clear', 'crystal', 'lord', 'state', 'preserve', 'loaf', 'fish', 'thing', 'general', 'settle']
# sentence 4: 	 ['year', 'lord', 'thousand', 'seven', 'seventy', 'spiritual', 'revelation', 'concede', 'england', 'favour', 'period', 'mrs', 'southcott', 'recently', 'attain', 'twentieth', 'bless', 'birthday', 'prophetic', 'private', 'life', 'guard', 'herald', 'sublime', 'appearance', 'announce', 'arrangement', 'swallowing', 'london', 'westminster', 'cock', 'lane', 'ghost', 'lay', 'round', 'dozen', 'year', 'rap', 'message', 'spirit', 'year', 'past', 'supernaturally', 'deficient', 'originality', 'rap', 'theirs', 'mere', 'message', 'earthly', 'order', 'event', 'lately', 'come', 'english', 'crown', 'people', 'congress', 'british', 'subject', 'america', 'strange', 'relate', 'prove', 'important', 'human', 'race', 'communication', 'receive', 'chicken', 'cock', 'lane', 'brood']
#
# Time to clean up everything: 0.1 mins

# %% [markdown]
# ## 5. Training Word2Vec Model

# %%
t = time()

print("\n")
print("#"*60)
print()
print("CPU check...")
cores = multiprocessing.cpu_count() # Count the number of cores in a computer
print("the number of processor: ", cores)
print()

print("Define Word2Vec Model...")
size = 300
window = 2
print("the size of dimensions of each word vector: ", size)
print("the size of window: ", size)
w2v_model = Word2Vec(min_count=5,
                     window=window,
                     size=size,
                     sample=6e-5, 
                     alpha=0.03, 
                     min_alpha=0.0007, 
                     negative=20,
                     workers=cores-1)

print()
print("buiding vocabulary...")
w2v_model.build_vocab(sentences, progress_per=10000)
print('Time to build vocab: {} mins'.format(round((time() - t) / 60, 2)))
print()


t = time()
print("training Word2Vec model...")
w2v_model.train(sentences, total_examples=w2v_model.corpus_count, epochs=1000, report_delay=1)
print("training is done...")
print()

print("saving trained word2vec model...")
file_path = './a_tale_of_two_cites_w2v_model.model'
print("file path:\t", file_path)
w2v_model.save(file_path)
print()

print("loading saved word2vec model...")
w2v_model = Word2Vec.load(file_path)
print()

print('Time to train the model: {} mins'.format(round((time() - t) / 60, 2)))
print()
# Out:
# INFO - 18:45:11: collecting all words and their counts
# INFO - 18:45:11: PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# INFO - 18:45:11: collected 7211 word types from a corpus of 55020 raw words and 2946 sentences
# INFO - 18:45:11: Loading a fresh vocabulary
# INFO - 18:45:11: effective_min_count=5 retains 2027 unique words (28% of original 7211, drops 5184)
# INFO - 18:45:11: effective_min_count=5 leaves 46152 word corpus (83% of original 55020, drops 8868)
# INFO - 18:45:11: deleting the raw counts dictionary of 7211 items
# ############################################################
#
# CPU check...
# the number of processor:  8
#
# Define Word2Vec Model...
# the size of dimensions of each word vector:  300
# the size of window:  300
#
# buiding vocabulary...
# INFO - 18:45:11: sample=6e-05 downsamples 1299 most-common words
# INFO - 18:45:11: downsampling leaves estimated 18584 word corpus (40.3% of prior 46152)
# INFO - 18:45:11: estimated required memory for 2027 words and 300 dimensions: 5878300 bytes
# INFO - 18:45:11: resetting layer weights
# INFO - 18:45:11: training model with 7 workers on 2027 vocabulary and 300 features, using sg=0 hs=0 sample=6e-05 negative=20 window=2
# INFO - 18:45:11: worker thread finished; awaiting finish of 6 more threads
# INFO - 18:45:11: worker thread finished; awaiting finish of 5 more threads
# INFO - 18:45:11: worker thread finished; awaiting finish of 4 more threads
# INFO - 18:45:11: worker thread finished; awaiting finish of 3 more threads
# INFO - 18:45:11: worker thread finished; awaiting finish of 2 more threads
# INFO - 18:45:11: worker thread finished; awaiting finish of 1 more threads
# INFO - 18:45:11: worker thread finished; awaiting finish of 0 more threads
# INFO - 18:45:11: EPOCH - 1 : training on 55020 raw words (18455 effective words) took 0.0s, 659175 effective words/s
# INFO - 18:45:11: worker thread finished; awaiting finish of 6 more threads
# INFO - 18:45:11: worker thread finished; awaiting finish of 5 more threads
# INFO - 18:45:11: worker thread finished; awaiting finish of 4 more threads
# INFO - 18:45:11: worker thread finished; awaiting finish of 3 more threads
# INFO - 18:45:11: worker thread finished; awaiting finish of 2 more threads
# INFO - 18:45:11: worker thread finished; awaiting finish of 1 more threads
# INFO - 18:45:11: worker thread finished; awaiting finish of 0 more threads
# INFO - 18:45:11: EPOCH - 2 : training on 55020 raw words (18501 effective words) took 0.0s, 686610 effective words/s
# INFO - 18:45:11: worker thread finished; awaiting finish of 6 more threads
# INFO - 18:45:11: worker thread finished; awaiting finish of 5 more threads
# INFO - 18:45:11: worker thread finished; awaiting finish of 4 more threads
# INFO - 18:45:11: worker thread finished; awaiting finish of 3 more threads
# INFO - 18:45:11: worker thread finished; awaiting finish of 2 more threads
# INFO - 18:45:11: worker thread finished; awaiting finish of 1 more threads
# INFO - 18:45:11: worker thread finished; awaiting finish of 0 more threads
# INFO - 18:45:11: EPOCH - 3 : training on 55020 raw words (18773 effective words) took 0.0s, 734738 effective words/s
# INFO - 18:45:11: worker thread finished; awaiting finish of 6 more threads
# INFO - 18:45:11: worker thread finished; awaiting finish of 5 more threads
# INFO - 18:45:11: worker thread finished; awaiting finish of 4 more threads
# INFO - 18:45:11: worker thread finished; awaiting finish of 3 more threads
# INFO - 18:45:11: worker thread finished; awaiting finish of 2 more threads
# INFO - 18:45:11: worker thread finished; awaiting finish of 1 more threads
# INFO - 18:45:11: worker thread finished; awaiting finish of 0 more threads
# INFO - 18:45:11: EPOCH - 4 : training on 55020 raw words (18598 effective words) took 0.0s, 720681 effective words/s
# INFO - 18:45:11: worker thread finished; awaiting finish of 6 more threads
# INFO - 18:45:11: worker thread finished; awaiting finish of 5 more threads
# INFO - 18:45:11: worker thread finished; awaiting finish of 4 more threads
# INFO - 18:45:11: worker thread finished; awaiting finish of 3 more threads
# INFO - 18:45:11: worker thread finished; awaiting finish of 2 more threads
# INFO - 18:45:11: worker thread finished; awaiting finish of 1 more threads
# INFO - 18:45:11: worker thread finished; awaiting finish of 0 more threads
# INFO - 18:45:11: EPOCH - 5 : training on 55020 raw words (18553 effective words) took 0.0s, 773695 effective words/s
# INFO - 18:45:11: worker thread finished; awaiting finish of 6 more threads
# INFO - 18:45:11: worker thread finished; awaiting finish of 5 more threads
# INFO - 18:45:11: worker thread finished; awaiting finish of 4 more threads
# INFO - 18:45:11: worker thread finished; awaiting finish of 3 more threads
# INFO - 18:45:11: worker thread finished; awaiting finish of 2 more threads
# INFO - 18:45:11: worker thread finished; awaiting finish of 1 more threads
# INFO - 18:45:11: worker thread finished; awaiting finish of 0 more threads
# INFO - 18:45:11: EPOCH - 6 : training on 55020 raw words (18641 effective words) took 0.0s, 697423 effective words/s
# INFO - 18:45:11: worker thread finished; awaiting finish of 6 more threads
# INFO - 18:45:11: worker thread finished; awaiting finish of 5 more threads
# INFO - 18:45:11: worker thread finished; awaiting finish of 4 more threads
# INFO - 18:45:11: worker thread finished; awaiting finish of 3 more threads
# INFO - 18:45:11: worker thread finished; awaiting finish of 2 more threads
# Time to build vocab: 0.0 mins
#
# training Word2Vec model...
# INFO - 18:45:11: worker thread finished; awaiting finish of 1 more threads
# INFO - 18:45:11: worker thread finished; awaiting finish of 0 more threads
# INFO - 18:45:11: EPOCH - 7 : training on 55020 raw words (18517 effective words) took 0.0s, 682941 effective words/s
# INFO - 18:45:11: worker thread finished; awaiting finish of 6 more threads
# INFO - 18:45:11: worker thread finished; awaiting finish of 5 more threads
# INFO - 18:45:11: worker thread finished; awaiting finish of 4 more threads
# INFO - 18:45:11: worker thread finished; awaiting finish of 3 more threads
# INFO - 18:45:11: worker thread finished; awaiting finish of 2 more threads
# INFO - 18:45:11: worker thread finished; awaiting finish of 1 more threads
# INFO - 18:45:11: worker thread finished; awaiting finish of 0 more threads
# INFO - 18:45:11: EPOCH - 8 : training on 55020 raw words (18511 effective words) took 0.0s, 718785 effective words/s
# INFO - 18:45:11: worker thread finished; awaiting finish of 6 more threads
# INFO - 18:45:11: worker thread finished; awaiting finish of 5 more threads
# INFO - 18:45:11: worker thread finished; awaiting finish of 4 more threads
# INFO - 18:45:11: worker thread finished; awaiting finish of 3 more threads
# INFO - 18:45:11: worker thread finished; awaiting finish of 2 more threads
# INFO - 18:45:11: worker thread finished; awaiting finish of 1 more threads
# INFO - 18:45:11: worker thread finished; awaiting finish of 0 more threads
# INFO - 18:45:11: EPOCH - 9 : training on 55020 raw words (18745 effective words) took 0.0s, 755395 effective words/s
# INFO - 18:45:11: worker thread finished; awaiting finish of 6 more threads
# INFO - 18:45:11: worker thread finished; awaiting finish of 5 more threads
# INFO - 18:45:11: worker thread finished; awaiting finish of 4 more threads
# INFO - 18:45:11: worker thread finished; awaiting finish of 3 more threads
# INFO - 18:45:11: worker thread finished; awaiting finish of 2 more threads
# INFO - 18:45:11: worker thread finished; awaiting finish of 1 more threads
# INFO - 18:45:11: worker thread finished; awaiting finish of 0 more threads
# INFO - 18:45:11: EPOCH - 10 : training on 55020 raw words (18464 effective words) took 0.0s, 719758 effective words/s
# INFO - 18:45:11: worker thread finished; awaiting finish of 6 more threads
# INFO - 18:45:11: worker thread finished; awaiting finish of 5 more threads
# INFO - 18:45:12: worker thread finished; awaiting finish of 4 more threads
# INFO - 18:45:12: worker thread finished; awaiting finish of 3 more threads
# INFO - 18:45:12: worker thread finished; awaiting finish of 2 more threads
# INFO - 18:45:12: worker thread finished; awaiting finish of 1 more threads
# INFO - 18:45:12: worker thread finished; awaiting finish of 0 more threads
# INFO - 18:45:12: EPOCH - 11 : training on 55020 raw words (18549 effective words) took 0.0s, 748229 effective words/s
# INFO - 18:45:12: worker thread finished; awaiting finish of 6 more threads
# INFO - 18:45:12: worker thread finished; awaiting finish of 5 more threads
# INFO - 18:45:12: worker thread finished; awaiting finish of 4 more threads
# INFO - 18:45:12: worker thread finished; awaiting finish of 3 more threads
# INFO - 18:45:12: worker thread finished; awaiting finish of 2 more threads
# INFO - 18:45:12: worker thread finished; awaiting finish of 1 more threads
# INFO - 18:45:12: worker thread finished; awaiting finish of 0 more threads
# INFO - 18:45:12: EPOCH - 12 : training on 55020 raw words (18628 effective words) took 0.0s, 727931 effective words/s
# INFO - 18:45:12: worker thread finished; awaiting finish of 6 more threads
# INFO - 18:45:12: worker thread finished; awaiting finish of 5 more threads
# INFO - 18:45:12: worker thread finished; awaiting finish of 4 more threads
# INFO - 18:45:12: worker thread finished; awaiting finish of 3 more threads
# INFO - 18:45:12: worker thread finished; awaiting finish of 2 more threads
# INFO - 18:45:12: worker thread finished; awaiting finish of 1 more threads
# INFO - 18:45:12: worker thread finished; awaiting finish of 0 more threads
# INFO - 18:45:12: EPOCH - 13 : training on 55020 raw words (18641 effective words) took 0.0s, 768886 effective words/s
# INFO - 18:45:12: worker thread finished; awaiting finish of 6 more threads
# INFO - 18:45:12: worker thread finished; awaiting finish of 5 more threads
# INFO - 18:45:12: worker thread finished; awaiting finish of 4 more threads
# INFO - 18:45:12: worker thread finished; awaiting finish of 3 more threads
# INFO - 18:45:12: worker thread finished; awaiting finish of 2 more threads
# INFO - 18:45:12: worker thread finished; awaiting finish of 1 more threads
# INFO - 18:45:12: worker thread finished; awaiting finish of 0 more threads
# INFO - 18:45:12: EPOCH - 14 : training on 55020 raw words (18611 effective words) took 0.0s, 683149 effective words/s
# INFO - 18:45:12: worker thread finished; awaiting finish of 6 more threads
# INFO - 18:45:12: worker thread finished; awaiting finish of 5 more threads
# INFO - 18:45:12: worker thread finished; awaiting finish of 4 more threads
# INFO - 18:45:12: worker thread finished; awaiting finish of 3 more threads
# INFO - 18:45:12: worker thread finished; awaiting finish of 2 more threads
# INFO - 18:45:12: worker thread finished; awaiting finish of 1 more threads
# INFO - 18:45:12: worker thread finished; awaiting finish of 0 more threads
# INFO - 18:45:12: EPOCH - 15 : training on 55020 raw words (18544 effective words) took 0.0s, 748472 effective words/s
# INFO - 18:45:12: worker thread finished; awaiting finish of 6 more threads
# INFO - 18:45:12: worker thread finished; awaiting finish of 5 more threads
# INFO - 18:45:12: worker thread finished; awaiting finish of 4 more threads
# INFO - 18:45:12: worker thread finished; awaiting finish of 3 more threads
# INFO - 18:45:12: worker thread finished; awaiting finish of 2 more threads
# INFO - 18:45:12: worker thread finished; awaiting finish of 1 more threads
# INFO - 18:45:12: worker thread finished; awaiting finish of 0 more threads
# INFO - 18:45:12: EPOCH - 16 : training on 55020 raw words (18602 effective words) took 0.0s, 758529 effective words/s
# INFO - 18:45:12: worker thread finished; awaiting finish of 6 more threads
# INFO - 18:45:12: worker thread finished; awaiting finish of 5 more threads
# INFO - 18:45:12: worker thread finished; awaiting finish of 4 more threads
# INFO - 18:45:12: worker thread finished; awaiting finish of 3 more threads
# INFO - 18:45:12: worker thread finished; awaiting finish of 2 more threads
# INFO - 18:45:12: worker thread finished; awaiting finish of 1 more threads
# INFO - 18:45:12: worker thread finished; awaiting finish of 0 more threads
# INFO - 18:45:12: EPOCH - 17 : training on 55020 raw words (18529 effective words) took 0.0s, 689689 effective words/s
# INFO - 18:45:12: worker thread finished; awaiting finish of 6 more threads
# INFO - 18:45:12: worker thread finished; awaiting finish of 5 more threads
# INFO - 18:45:12: worker thread finished; awaiting finish of 4 more threads
# INFO - 18:45:12: worker thread finished; awaiting finish of 3 more threads
# INFO - 18:45:12: worker thread finished; awaiting finish of 2 more threads
# INFO - 18:45:12: worker thread finished; awaiting finish of 1 more threads
# INFO - 18:45:12: worker thread finished; awaiting finish of 0 more threads
# INFO - 18:45:12: EPOCH - 18 : training on 55020 raw words (18590 effective words) took 0.0s, 668412 effective words/s
# INFO - 18:45:12: worker thread finished; awaiting finish of 6 more threads
# INFO - 18:45:12: worker thread finished; awaiting finish of 5 more threads
# INFO - 18:45:12: worker thread finished; awaiting finish of 4 more threads
# INFO - 18:45:12: worker thread finished; awaiting finish of 3 more threads
# INFO - 18:45:12: worker thread finished; awaiting finish of 2 more threads
# INFO - 18:45:12: worker thread finished; awaiting finish of 1 more threads
# INFO - 18:45:12: worker thread finished; awaiting finish of 0 more threads
# INFO - 18:45:12: EPOCH - 19 : training on 55020 raw words (18640 effective words) took 0.0s, 728774 effective words/s
# INFO - 18:45:12: worker thread finished; awaiting finish of 6 more threads
# INFO - 18:45:12: worker thread finished; awaiting finish of 5 more threads
# INFO - 18:45:12: worker thread finished; awaiting finish of 4 more threads
# INFO - 18:45:12: worker thread finished; awaiting finish of 3 more threads
# INFO - 18:45:12: worker thread finished; awaiting finish of 2 more threads
# INFO - 18:45:12: worker thread finished; awaiting finish of 1 more threads
# INFO - 18:45:12: worker thread finished; awaiting finish of 0 more threads
# INFO - 18:45:12: EPOCH - 20 : training on 55020 raw words (18474 effective words) took 0.0s, 812523 effective words/s
# INFO - 18:45:12: worker thread finished; awaiting finish of 6 more threads
# INFO - 18:45:12: worker thread finished; awaiting finish of 5 more threads
# INFO - 18:45:12: worker thread finished; awaiting finish of 4 more threads
# INFO - 18:45:12: worker thread finished; awaiting finish of 3 more threads
# INFO - 18:45:12: worker thread finished; awaiting finish of 2 more threads
# INFO - 18:45:12: worker thread finished; awaiting finish of 1 more threads
# INFO - 18:45:12: worker thread finished; awaiting finish of 0 more threads
# INFO - 18:45:12: EPOCH - 21 : training on 55020 raw words (18570 effective words) took 0.0s, 656424 effective words/s
# INFO - 18:45:12: worker thread finished; awaiting finish of 6 more threads
# INFO - 18:45:12: worker thread finished; awaiting finish of 5 more threads
# INFO - 18:45:12: worker thread finished; awaiting finish of 4 more threads
# INFO - 18:45:12: worker thread finished; awaiting finish of 3 more threads
# INFO - 18:45:12: worker thread finished; awaiting finish of 2 more threads
# INFO - 18:45:12: worker thread finished; awaiting finish of 1 more threads
# INFO - 18:45:12: worker thread finished; awaiting finish of 0 more threads
# INFO - 18:45:12: EPOCH - 22 : training on 55020 raw words (18773 effective words) took 0.0s, 671908 effective words/s
# INFO - 18:45:12: worker thread finished; awaiting finish of 6 more threads
# INFO - 18:45:12: worker thread finished; awaiting finish of 5 more threads
# INFO - 18:45:12: worker thread finished; awaiting finish of 4 more threads
# INFO - 18:45:12: worker thread finished; awaiting finish of 3 more threads
# INFO - 18:45:12: worker thread finished; awaiting finish of 2 more threads
# INFO - 18:45:12: worker thread finished; awaiting finish of 1 more threads
# INFO - 18:45:12: worker thread finished; awaiting finish of 0 more threads
# INFO - 18:45:12: EPOCH - 23 : training on 55020 raw words (18688 effective words) took 0.0s, 745452 effective words/s
# INFO - 18:45:12: worker thread finished; awaiting finish of 6 more threads
# INFO - 18:45:12: worker thread finished; awaiting finish of 5 more threads
# INFO - 18:45:12: worker thread finished; awaiting finish of 4 more threads
# INFO - 18:45:12: worker thread finished; awaiting finish of 3 more threads
# INFO - 18:45:12: worker thread finished; awaiting finish of 2 more threads
# INFO - 18:45:12: worker thread finished; awaiting finish of 1 more threads
# INFO - 18:45:12: worker thread finished; awaiting finish of 0 more threads
# INFO - 18:45:12: EPOCH - 24 : training on 55020 raw words (18601 effective words) took 0.0s, 677687 effective words/s
# INFO - 18:45:12: worker thread finished; awaiting finish of 6 more threads
# INFO - 18:45:12: worker thread finished; awaiting finish of 5 more threads
# INFO - 18:45:12: worker thread finished; awaiting finish of 4 more threads
# INFO - 18:45:12: worker thread finished; awaiting finish of 3 more threads
# INFO - 18:45:12: worker thread finished; awaiting finish of 2 more threads
# INFO - 18:45:12: worker thread finished; awaiting finish of 1 more threads
# INFO - 18:45:12: worker thread finished; awaiting finish of 0 more threads
# INFO - 18:45:12: EPOCH - 25 : training on 55020 raw words (18543 effective words) took 0.0s, 731053 effective words/s
# INFO - 18:45:12: worker thread finished; awaiting finish of 6 more threads
# INFO - 18:45:12: worker thread finished; awaiting finish of 5 more threads
# INFO - 18:45:12: worker thread finished; awaiting finish of 4 more threads
# INFO - 18:45:12: worker thread finished; awaiting finish of 3 more threads
# INFO - 18:45:12: worker thread finished; awaiting finish of 2 more threads
# INFO - 18:45:12: worker thread finished; awaiting finish of 1 more threads
# INFO - 18:45:12: worker thread finished; awaiting finish of 0 more threads
# INFO - 18:45:12: EPOCH - 26 : training on 55020 raw words (18571 effective words) took 0.0s, 669275 effective words/s
# INFO - 18:45:12: worker thread finished; awaiting finish of 6 more threads
# INFO - 18:45:12: worker thread finished; awaiting finish of 5 more threads
# INFO - 18:45:12: worker thread finished; awaiting finish of 4 more threads
# INFO - 18:45:12: worker thread finished; awaiting finish of 3 more threads
# INFO - 18:45:12: worker thread finished; awaiting finish of 2 more threads
# INFO - 18:45:12: worker thread finished; awaiting finish of 1 more threads
# INFO - 18:45:12: worker thread finished; awaiting finish of 0 more threads
# INFO - 18:45:12: EPOCH - 27 : training on 55020 raw words (18555 effective words) took 0.0s, 752265 effective words/s
# INFO - 18:45:12: worker thread finished; awaiting finish of 6 more threads
# INFO - 18:45:12: worker thread finished; awaiting finish of 5 more threads
# INFO - 18:45:12: worker thread finished; awaiting finish of 4 more threads
# INFO - 18:45:12: worker thread finished; awaiting finish of 3 more threads
# INFO - 18:45:12: worker thread finished; awaiting finish of 2 more threads
# INFO - 18:45:12: worker thread finished; awaiting finish of 1 more threads
# INFO - 18:45:12: worker thread finished; awaiting finish of 0 more threads
# INFO - 18:45
worker thread finished; awaiting finish of 6 more threads
# INFO - 18:45:37: worker thread finished; awaiting finish of 5 more threads
# INFO - 18:45:37: worker thread finished; awaiting finish of 4 more threads
# INFO - 18:45:37: worker thread finished; awaiting finish of 3 more threads
# INFO - 18:45:37: worker thread finished; awaiting finish of 2 more threads
# INFO - 18:45:37: worker thread finished; awaiting finish of 1 more threads
# INFO - 18:45:37: worker thread finished; awaiting finish of 0 more threads
# INFO - 18:45:37: EPOCH - 984 : training on 55020 raw words (18494 effective words) took 0.0s, 788018 effective words/s
# INFO - 18:45:37: worker thread finished; awaiting finish of 6 more threads
# INFO - 18:45:37: worker thread finished; awaiting finish of 5 more threads
# INFO - 18:45:37: worker thread finished; awaiting finish of 4 more threads
# INFO - 18:45:37: worker thread finished; awaiting finish of 3 more threads
# INFO - 18:45:37: worker thread finished; awaiting finish of 2 more threads
# INFO - 18:45:37: worker thread finished; awaiting finish of 1 more threads
# INFO - 18:45:37: worker thread finished; awaiting finish of 0 more threads
# INFO - 18:45:37: EPOCH - 985 : training on 55020 raw words (18526 effective words) took 0.0s, 837631 effective words/s
# INFO - 18:45:37: worker thread finished; awaiting finish of 6 more threads
# INFO - 18:45:37: worker thread finished; awaiting finish of 5 more threads
# INFO - 18:45:37: worker thread finished; awaiting finish of 4 more threads
# INFO - 18:45:37: worker thread finished; awaiting finish of 3 more threads
# INFO - 18:45:37: worker thread finished; awaiting finish of 2 more threads
# INFO - 18:45:37: worker thread finished; awaiting finish of 1 more threads
# INFO - 18:45:37: worker thread finished; awaiting finish of 0 more threads
# INFO - 18:45:37: EPOCH - 986 : training on 55020 raw words (18577 effective words) took 0.0s, 791559 effective words/s
# INFO - 18:45:37: worker thread finished; awaiting finish of 6 more threads
# INFO - 18:45:37: worker thread finished; awaiting finish of 5 more threads
# INFO - 18:45:37: worker thread finished; awaiting finish of 4 more threads
# INFO - 18:45:37: worker thread finished; awaiting finish of 3 more threads
# INFO - 18:45:37: worker thread finished; awaiting finish of 2 more threads
# INFO - 18:45:37: worker thread finished; awaiting finish of 1 more threads
# INFO - 18:45:37: worker thread finished; awaiting finish of 0 more threads
# INFO - 18:45:37: EPOCH - 987 : training on 55020 raw words (18610 effective words) took 0.0s, 847954 effective words/s
# INFO - 18:45:37: worker thread finished; awaiting finish of 6 more threads
# INFO - 18:45:37: worker thread finished; awaiting finish of 5 more threads
# INFO - 18:45:37: worker thread finished; awaiting finish of 4 more threads
# INFO - 18:45:37: worker thread finished; awaiting finish of 3 more threads
# INFO - 18:45:37: worker thread finished; awaiting finish of 2 more threads
# INFO - 18:45:37: worker thread finished; awaiting finish of 1 more threads
# INFO - 18:45:37: worker thread finished; awaiting finish of 0 more threads
# INFO - 18:45:37: EPOCH - 988 : training on 55020 raw words (18626 effective words) took 0.0s, 767956 effective words/s
# INFO - 18:45:37: worker thread finished; awaiting finish of 6 more threads
# INFO - 18:45:37: worker thread finished; awaiting finish of 5 more threads
# INFO - 18:45:37: worker thread finished; awaiting finish of 4 more threads
# INFO - 18:45:37: worker thread finished; awaiting finish of 3 more threads
# INFO - 18:45:37: worker thread finished; awaiting finish of 2 more threads
# INFO - 18:45:37: worker thread finished; awaiting finish of 1 more threads
# INFO - 18:45:37: worker thread finished; awaiting finish of 0 more threads
# INFO - 18:45:37: EPOCH - 989 : training on 55020 raw words (18684 effective words) took 0.0s, 807858 effective words/s
# INFO - 18:45:37: worker thread finished; awaiting finish of 6 more threads
# INFO - 18:45:37: worker thread finished; awaiting finish of 5 more threads
# INFO - 18:45:37: worker thread finished; awaiting finish of 4 more threads
# INFO - 18:45:37: worker thread finished; awaiting finish of 3 more threads
# INFO - 18:45:37: worker thread finished; awaiting finish of 2 more threads
# INFO - 18:45:37: worker thread finished; awaiting finish of 1 more threads
# INFO - 18:45:37: worker thread finished; awaiting finish of 0 more threads
# INFO - 18:45:37: EPOCH - 990 : training on 55020 raw words (18597 effective words) took 0.0s, 824263 effective words/s
# INFO - 18:45:37: worker thread finished; awaiting finish of 6 more threads
# INFO - 18:45:37: worker thread finished; awaiting finish of 5 more threads
# INFO - 18:45:37: worker thread finished; awaiting finish of 4 more threads
# INFO - 18:45:37: worker thread finished; awaiting finish of 3 more threads
# INFO - 18:45:37: worker thread finished; awaiting finish of 2 more threads
# INFO - 18:45:37: worker thread finished; awaiting finish of 1 more threads
# INFO - 18:45:37: worker thread finished; awaiting finish of 0 more threads
# INFO - 18:45:37: EPOCH - 991 : training on 55020 raw words (18441 effective words) took 0.0s, 799891 effective words/s
# INFO - 18:45:37: worker thread finished; awaiting finish of 6 more threads
# INFO - 18:45:37: worker thread finished; awaiting finish of 5 more threads
# INFO - 18:45:37: worker thread finished; awaiting finish of 4 more threads
# INFO - 18:45:37: worker thread finished; awaiting finish of 3 more threads
# INFO - 18:45:37: worker thread finished; awaiting finish of 2 more threads
# INFO - 18:45:37: worker thread finished; awaiting finish of 1 more threads
# INFO - 18:45:37: worker thread finished; awaiting finish of 0 more threads
# INFO - 18:45:37: EPOCH - 992 : training on 55020 raw words (18716 effective words) took 0.0s, 839693 effective words/s
# INFO - 18:45:37: worker thread finished; awaiting finish of 6 more threads
# INFO - 18:45:37: worker thread finished; awaiting finish of 5 more threads
# INFO - 18:45:37: worker thread finished; awaiting finish of 4 more threads
# INFO - 18:45:37: worker thread finished; awaiting finish of 3 more threads
# INFO - 18:45:37: worker thread finished; awaiting finish of 2 more threads
# INFO - 18:45:37: worker thread finished; awaiting finish of 1 more threads
# INFO - 18:45:37: worker thread finished; awaiting finish of 0 more threads
# INFO - 18:45:37: EPOCH - 993 : training on 55020 raw words (18559 effective words) took 0.0s, 783297 effective words/s
# INFO - 18:45:37: worker thread finished; awaiting finish of 6 more threads
# INFO - 18:45:37: worker thread finished; awaiting finish of 5 more threads
# INFO - 18:45:37: worker thread finished; awaiting finish of 4 more threads
# INFO - 18:45:37: worker thread finished; awaiting finish of 3 more threads
# INFO - 18:45:37: worker thread finished; awaiting finish of 2 more threads
# INFO - 18:45:37: worker thread finished; awaiting finish of 1 more threads
# INFO - 18:45:37: worker thread finished; awaiting finish of 0 more threads
# INFO - 18:45:37: EPOCH - 994 : training on 55020 raw words (18517 effective words) took 0.0s, 794077 effective words/s
# INFO - 18:45:37: worker thread finished; awaiting finish of 6 more threads
# INFO - 18:45:37: worker thread finished; awaiting finish of 5 more threads
# INFO - 18:45:37: worker thread finished; awaiting finish of 4 more threads
# INFO - 18:45:37: worker thread finished; awaiting finish of 3 more threads
# INFO - 18:45:37: worker thread finished; awaiting finish of 2 more threads
# INFO - 18:45:37: worker thread finished; awaiting finish of 1 more threads
# INFO - 18:45:37: worker thread finished; awaiting finish of 0 more threads
# INFO - 18:45:37: EPOCH - 995 : training on 55020 raw words (18614 effective words) took 0.0s, 833995 effective words/s
# INFO - 18:45:37: worker thread finished; awaiting finish of 6 more threads
# INFO - 18:45:37: worker thread finished; awaiting finish of 5 more threads
# INFO - 18:45:37: worker thread finished; awaiting finish of 4 more threads
# INFO - 18:45:37: worker thread finished; awaiting finish of 3 more threads
# INFO - 18:45:37: worker thread finished; awaiting finish of 2 more threads
# INFO - 18:45:37: worker thread finished; awaiting finish of 1 more threads
# INFO - 18:45:37: worker thread finished; awaiting finish of 0 more threads
# INFO - 18:45:37: EPOCH - 996 : training on 55020 raw words (18605 effective words) took 0.0s, 901005 effective words/s
# INFO - 18:45:37: worker thread finished; awaiting finish of 6 more threads
# INFO - 18:45:37: worker thread finished; awaiting finish of 5 more threads
# INFO - 18:45:37: worker thread finished; awaiting finish of 4 more threads
# INFO - 18:45:37: worker thread finished; awaiting finish of 3 more threads
# INFO - 18:45:37: worker thread finished; awaiting finish of 2 more threads
# INFO - 18:45:37: worker thread finished; awaiting finish of 1 more threads
# INFO - 18:45:37: worker thread finished; awaiting finish of 0 more threads
# INFO - 18:45:37: EPOCH - 997 : training on 55020 raw words (18602 effective words) took 0.0s, 891129 effective words/s
# INFO - 18:45:37: worker thread finished; awaiting finish of 6 more threads
# INFO - 18:45:37: worker thread finished; awaiting finish of 5 more threads
# INFO - 18:45:37: worker thread finished; awaiting finish of 4 more threads
# INFO - 18:45:37: worker thread finished; awaiting finish of 3 more threads
# INFO - 18:45:37: worker thread finished; awaiting finish of 2 more threads
# INFO - 18:45:37: worker thread finished; awaiting finish of 1 more threads
# INFO - 18:45:37: worker thread finished; awaiting finish of 0 more threads
# INFO - 18:45:37: EPOCH - 998 : training on 55020 raw words (18609 effective words) took 0.0s, 840555 effective words/s
# INFO - 18:45:37: worker thread finished; awaiting finish of 6 more threads
# INFO - 18:45:37: worker thread finished; awaiting finish of 5 more threads
# INFO - 18:45:37: worker thread finished; awaiting finish of 4 more threads
# INFO - 18:45:37: worker thread finished; awaiting finish of 3 more threads
# INFO - 18:45:37: worker thread finished; awaiting finish of 2 more threads
# INFO - 18:45:37: worker thread finished; awaiting finish of 1 more threads
# INFO - 18:45:37: worker thread finished; awaiting finish of 0 more threads
# INFO - 18:45:37: EPOCH - 999 : training on 55020 raw words (18585 effective words) took 0.0s, 823401 effective words/s
# INFO - 18:45:37: worker thread finished; awaiting finish of 6 more threads
# INFO - 18:45:37: worker thread finished; awaiting finish of 5 more threads
# INFO - 18:45:37: worker thread finished; awaiting finish of 4 more threads
# INFO - 18:45:37: worker thread finished; awaiting finish of 3 more threads
# INFO - 18:45:37: worker thread finished; awaiting finish of 2 more threads
# INFO - 18:45:37: worker thread finished; awaiting finish of 1 more threads
# INFO - 18:45:37: worker thread finished; awaiting finish of 0 more threads
# INFO - 18:45:37: EPOCH - 1000 : training on 55020 raw words (18563 effective words) took 0.0s, 854187 effective words/s
# INFO - 18:45:37: training on a 55020000 raw words (18588133 effective words) took 26.0s, 715956 effective words/s
# INFO - 18:45:37: saving Word2Vec object under ./a_tale_of_two_cites_w2v_model.model, separately None
# INFO - 18:45:37: not storing attribute vectors_norm
# INFO - 18:45:37: not storing attribute cum_table
# INFO - 18:45:37: saved ./a_tale_of_two_cites_w2v_model.model
# INFO - 18:45:37: loading Word2Vec object from ./a_tale_of_two_cites_w2v_model.model
# INFO - 18:45:37: loading wv recursively from ./a_tale_of_two_cites_w2v_model.model.wv.* with mmap=None
# INFO - 18:45:37: setting ignored attribute vectors_norm to None
# INFO - 18:45:37: loading vocabulary recursively from ./a_tale_of_two_cites_w2v_model.model.vocabulary.* with mmap=None
# INFO - 18:45:37: loading trainables recursively from ./a_tale_of_two_cites_w2v_model.model.trainables.* with mmap=None
# INFO - 18:45:37: setting ignored attribute cum_table to None
# INFO - 18:45:37: loaded ./a_tale_of_two_cites_w2v_model.model
# training is done...
#
# saving trained word2vec model...
# file path:	 ./a_tale_of_two_cites_w2v_model.model
#
# loading saved word2vec model...
#
# Time to train the model: 0.43 mins

# %% [markdown]
# ## 6. Word Embedding

# %%
print("\n")
print("#"*60)
print("checking word embeddings...")

word_vectors = w2v_model.wv
print("total number of words: ", len(word_vectors.index2word))
print()
print("5 example of word vectors")
for i in range(5):
    word = word_vectors.index2word[i]
    print(f"[{i+1}]: \t", word)
    print(word_vectors.get_vector(word))
# Out:
# ############################################################
# checking word embeddings...
# total number of words:  2027
#
# 5 example of word vectors
# [1]: 	 say
# [-0.22684409  0.3351418   0.2780638   0.726287    0.24031517 -0.07069345
#  -0.26963487  0.47791085 -0.19196719  0.40050018  0.2004106   0.16710305
#  -0.05349459  0.41047165 -0.10526986  0.19142893  0.76323444  0.08946665
#  -0.23704928 -0.47357577  0.9816061   0.838462   -0.45092446  0.6224159
#  -0.22482416 -0.10191855  0.12242197  0.51187754  0.36495748 -0.50245255
#  -0.15215084 -0.5859289  -0.54497224 -0.5171106  -0.0673593  -0.08378996
#  -0.24326457  0.29923555 -0.4950293   0.5741782   0.31099552  0.0102893
#   0.7450689  -0.01576611  0.2635877   0.31188634  0.26991543  0.15142359
#  -0.34636065 -0.06319993  0.75842804  0.08296914 -0.13957879  0.37214518
#   0.22197135  0.37792462 -0.19956976 -0.03266881  0.18327974  0.8174667
#  -0.00441718  0.4055392  -0.37337598  0.04198312 -0.00872237 -0.16994995
#   0.3208712   0.20936227 -0.38057038 -0.22321826  0.33201477  0.7789344
#   0.4581303  -0.15591808  0.80361396  0.01068609 -0.52171695  0.11102667
#  -0.6965509  -0.2735517  -0.10055449 -0.92896354  0.067476    0.2306754
#   0.4123077  -0.5656524   0.31272864  0.42001712  0.7806415   0.12023418
#   0.1861154  -0.19970034  0.22093059 -0.05482882 -0.39446986  0.269589
#  -0.87008363 -0.3334835  -0.26217756  0.5087722   0.14877069  0.35773647
#  -0.11906811 -0.14847733  0.08835018  0.06645027 -0.23647624 -0.48372668
#  -0.5649574   0.87803143 -0.27718988 -0.7872152   0.46156493  0.40448922
#  -0.85667884 -0.7111351   0.07851139  0.20143719  0.33870968 -0.17175564
#   0.01473359 -0.21253584  0.3373752   0.28565776 -0.0646312  -0.49042025
#  -0.15615012 -0.4239328   0.06130712 -0.01169625  0.2946359   0.37587172
#  -0.22727156  0.13502276 -0.55102694 -0.22642279 -0.35197154  0.6175617
#   0.2975371   0.6053336   0.01692712 -0.27402362 -0.3767969  -0.15333587
#  -0.6142707  -0.63866687 -0.6299825  -0.46286032  0.3041981   1.1877112
#   0.49119207 -0.07354026 -0.01773118 -0.5140651  -0.12756713 -0.23928148
#   0.23500474  0.35310403  0.03463814  0.59732574 -0.75477916 -0.6142747
#   0.14860979 -0.34643596  0.17290784  0.7178291  -0.59268916  0.65100753
#  -0.3065851  -0.2069782  -0.15081821  0.05719651 -0.5500606   0.14241064
#  -0.4695315  -0.09766693 -0.3635522   0.3358798  -0.6728564   0.4000148
#  -6.74652681e-03  5.08095741e-01  4.07169431e-01  5.12049735e-01
#   4.11020339e-01  2.80000627e-01 -9.77085382e-02 -6.08043551e-01
#  -3.76881659e-01  3.51657450e-01 -3.39125991e-01 -2.03427494e-01
#   3.83071274e-01  3.97851706e-01 -1.10557817e-01  5.86897373e-01
#   2.14830160e-01  3.10468823e-01 -2.69437045e-01 -3.96987289e-01
#   3.00265282e-01 -2.27634713e-01 -3.95441294e-01 -9.03420150e-01
#  -8.76080915e-02 -6.13890514e-02 -1.18526280e-01 -2.69717515e-01
#  -5.52810490e-01 -4.13725585e-01  3.39687198e-01 -8.84312630e-01
#   1.72542911e-02  1.62632674e-01  2.84585297e-01  1.05067581e-01
#   2.85187006e-01 -1.23797274e+00 -9.87324044e-02  5.45468926e-01
#   5.75876594e-01 -1.29056340e-02  1.83163792e-01 -7.69634902e-01
#   2.34059229e-01  5.82237504e-02 -6.23598039e-01 -2.20311806e-01
#  -4.70040858e-01 -7.79911816e-01  4.15671051e-01 -1.19523656e+00
#   1.23684950e-01  2.39190832e-01 -6.35256171e-01  1.13272905e-01
#  -2.20626835e-02  7.21195996e-01 -2.73125172e-01 -6.95372403e-01
#  -5.26271641e-01 -9.35038686e-01 -6.46484435e-01 -1.11835919e-01
#   1.73658386e-01  2.35501483e-01  2.82994866e-01 -5.41470766e-01
#   5.09934306e-01  6.65659249e-01  1.15242124e+00 -1.89756751e-02
#   1.19040966e+00 -7.91896641e-01 -8.53197455e-01 -3.00072064e-03
#   3.55295956e-01 -1.93774588e-02 -3.99712831e-01 -2.72097308e-02
#  -1.16804790e+00 -5.22869885e-01 -2.69500494e-01  3.34184617e-01
#   6.47030890e-01 -4.71883386e-01 -1.72360629e-01 -3.40424031e-01
#   1.86365902e-01  4.39205706e-01  3.94807011e-01  3.90736938e-01
#  -5.52309630e-03  2.16682199e-02  7.74846077e-01 -5.71243107e-01
#   2.61778533e-01 -7.69165754e-01  3.41082603e-01 -6.44841865e-02
#  -5.82475141e-02 -3.27465415e-01  2.75972039e-01  4.70282674e-01
#  -2.80230224e-01  1.60043776e-01 -4.06450987e-01  2.90325552e-01]

# %% [markdown]
# ## 7. Location Sentiment Analysis
# ### - Querying location and Selecting k-nearest neighbor words

# %%
print("\n")
print("#"*60)
print("Querying location word in word embeddings...")
print()

location = 'london'
k = 20
print(f"target location word: \t {location}")
print(f"the number of neighbor words: \t {k}")

print()
print("k-nearest neighbor words")
k_neighbors = word_vectors.most_similar(positive=[location], topn=k)
print("No. word \t\tdistance")
for i, (neighbor_word, distance) in enumerate(k_neighbors):
    print(f"{i+1}. {neighbor_word}\t\t {distance}")
# Out:
# INFO - 18:45:37: precomputing L2-norms of word weight vectors
# ############################################################
# Querying location word in word embeddings...
#
# target location word: 	 london
# the number of neighbor words: 	 20
#
# k-nearest neighbor words
# No. word 		distance
# 1. tellson		 0.2956874370574951
# 2. mail		 0.25125938653945923
# 3. busy		 0.24844637513160706
# 4. partner		 0.24216477572917938
# 5. worthy		 0.2364470660686493
# 6. orphan		 0.21845492720603943
# 7. plane		 0.21606044471263885
# 8. elderly		 0.20789942145347595
# 9. blind		 0.2076665163040161
# 10. arrive		 0.20607450604438782
# 11. seventy		 0.20242592692375183
# 12. bank		 0.20105814933776855
# 13. lodging		 0.19967180490493774
# 14. year		 0.19859161972999573
# 15. tellson_s		 0.19798478484153748
# 16. harness		 0.19285878539085388
# 17. description		 0.19185477495193481
# 18. hay		 0.18657512962818146
# 19. occupation		 0.18314382433891296
# 20. peace		 0.18270191550254822

# %% [markdown]
# ### - Applying sentiment score to each selected words

# %%
print("\n")
print("#"*60)
print("example of SentiWordNet Senti-Synsets...")
print()

target_word = 'good'
print("target word: ", target_word)

def synset_senti_score(target_word):
    synsets = swn.senti_synsets(target_word)
    print('synset name\tpositive \tnegative \tobjective')
    for ss in synsets:
        print(ss.synset.name(),"\t", ss.pos_score(), "\t\t", ss.neg_score(), "\t\t", ss.obj_score())

print(f"sentiment score of synsets of {target_word}")
synset_senti_score(target_word)
# Out:
# ############################################################
# example of SentiWordNet Senti-Synsets...
#
# target word:  good
# sentiment score of synsets of good
# synset name	positive 	negative 	objective
# good.n.01 	 0.5 		 0.0 		 0.5
# good.n.02 	 0.875 		 0.0 		 0.125
# good.n.03 	 0.625 		 0.0 		 0.375
# commodity.n.01 	 0.0 		 0.0 		 1.0
# good.a.01 	 0.75 		 0.0 		 0.25
# full.s.06 	 0.0 		 0.0 		 1.0
# good.a.03 	 1.0 		 0.0 		 0.0
# estimable.s.02 	 1.0 		 0.0 		 0.0
# beneficial.s.01 	 0.625 		 0.0 		 0.375
# good.s.06 	 1.0 		 0.0 		 0.0
# good.s.07 	 0.75 		 0.0 		 0.25
# adept.s.01 	 0.625 		 0.0 		 0.375
# good.s.09 	 0.625 		 0.0 		 0.375
# dear.s.02 	 0.5 		 0.0 		 0.5
# dependable.s.04 	 0.5 		 0.0 		 0.5
# good.s.12 	 0.375 		 0.0 		 0.625
# good.s.13 	 0.625 		 0.0 		 0.375
# effective.s.04 	 0.0 		 0.0 		 1.0
# good.s.15 	 0.625 		 0.0 		 0.375
# good.s.16 	 0.75 		 0.0 		 0.25
# good.s.17 	 0.75 		 0.0 		 0.25
# good.s.18 	 0.875 		 0.0 		 0.125
# good.s.19 	 0.5 		 0.0 		 0.5
# good.s.20 	 0.375 		 0.125 		 0.5
# good.s.21 	 0.75 		 0.0 		 0.25
# well.r.01 	 0.375 		 0.0 		 0.625
# thoroughly.r.02 	 0.0 		 0.0 		 1.0

# %%
print("\n")
print("#"*60)

obj_threshold = 0.25

print("custom sentiment score")
print(f"1) if objective score <= {obj_threshold}, then the synset is used for sentiment analyis...")
print("2) mean of (positive score - negative score) of each synset is the final sentiment score")
print("maximum positive score: 1, maximm negative score: -1, neutral: 0 \t range(-1~1)")
print()
print("example of custom sentiment score")
print()



def synset_senti_score(target_word, obj_threshold):
    synsets = swn.senti_synsets(target_word)
    print("target word: ", target_word)
    print('synset name\tpositive \tnegative \tobjective')
    senti_score_list = []
    for ss in synsets:
        pos = ss.pos_score()
        neg = ss.neg_score()
        obj = ss.obj_score()
        if obj <= obj_threshold:
            print(ss.synset.name(),"\t", pos, "\t\t", neg, "\t\t", obj, '\t(used for SA)')
            senti_score_list.append(pos-neg)
        else:
            print(ss.synset.name(),"\t", pos, "\t\t", neg, "\t\t", obj)
    
    if len(senti_score_list) == 0:
        senti_score = 0.
    else:
        senti_score = np.mean(senti_score_list)
    
    return senti_score

print()
target_word = 'good'
print(f"\nsentiment score of '{target_word}': {synset_senti_score(target_word, obj_threshold)}")
print("-"*50)

print()
target_word = 'bad'
print(f"\nsentiment score of '{target_word}': {synset_senti_score(target_word, obj_threshold)}")
print("-"*50)

print()
target_word = 'school'
print(f"\nsentiment score of '{target_word}': {synset_senti_score(target_word, obj_threshold)}")
print("-"*50)
# Out:
# ############################################################
# custom sentiment score
# 1) if objective score <= 0.25, then the synset is used for sentiment analyis...
# 2) mean of (positive score - negative score) of each synset is the final sentiment score
# maximum positive score: 1, maximm negative score: -1, neutral: 0 	 range(-1~1)
#
# example of custom sentiment score
#
#
# target word:  good
# synset name	positive 	negative 	objective
# good.n.01 	 0.5 		 0.0 		 0.5
# good.n.02 	 0.875 		 0.0 		 0.125 	(used for SA)
# good.n.03 	 0.625 		 0.0 		 0.375
# commodity.n.01 	 0.0 		 0.0 		 1.0
# good.a.01 	 0.75 		 0.0 		 0.25 	(used for SA)
# full.s.06 	 0.0 		 0.0 		 1.0
# good.a.03 	 1.0 		 0.0 		 0.0 	(used for SA)
# estimable.s.02 	 1.0 		 0.0 		 0.0 	(used for SA)
# beneficial.s.01 	 0.625 		 0.0 		 0.375
# good.s.06 	 1.0 		 0.0 		 0.0 	(used for SA)
# good.s.07 	 0.75 		 0.0 		 0.25 	(used for SA)
# adept.s.01 	 0.625 		 0.0 		 0.375
# good.s.09 	 0.625 		 0.0 		 0.375
# dear.s.02 	 0.5 		 0.0 		 0.5
# dependable.s.04 	 0.5 		 0.0 		 0.5
# good.s.12 	 0.375 		 0.0 		 0.625
# good.s.13 	 0.625 		 0.0 		 0.375
# effective.s.04 	 0.0 		 0.0 		 1.0
# good.s.15 	 0.625 		 0.0 		 0.375
# good.s.16 	 0.75 		 0.0 		 0.25 	(used for SA)
# good.s.17 	 0.75 		 0.0 		 0.25 	(used for SA)
# good.s.18 	 0.875 		 0.0 		 0.125 	(used for SA)
# good.s.19 	 0.5 		 0.0 		 0.5
# good.s.20 	 0.375 		 0.125 		 0.5
# good.s.21 	 0.75 		 0.0 		 0.25 	(used for SA)
# well.r.01 	 0.375 		 0.0 		 0.625
# thoroughly.r.02 	 0.0 		 0.0 		 1.0
#
# sentiment score of 'good': 0.85
# --------------------------------------------------
#
# target word:  bad
# synset name	positive 	negative 	objective
# bad.n.01 	 0.0 		 0.875 		 0.125 	(used for SA)
# bad.a.01 	 0.0 		 0.625 		 0.375
# bad.s.02 	 0.25 		 0.25 		 0.5
# bad.s.03 	 0.0 		 0.75 		 0.25 	(used for SA)
# bad.s.04 	 0.0 		 0.75 		 0.25 	(used for SA)
# regretful.a.01 	 0.0 		 0.625 		 0.375
# bad.s.06 	 0.0 		 0.75 		 0.25 	(used for SA)
# bad.s.07 	 0.0 		 0.625 		 0.375
# bad.s.08 	 0.0 		 0.5 		 0.5
# bad.s.09 	 0.0 		 0.75 		 0.25 	(used for SA)
# bad.s.10 	 0.0 		 1.0 		 0.0 	(used for SA)
# bad.s.11 	 0.0 		 0.375 		 0.625
# bad.s.12 	 0.0 		 0.75 		 0.25 	(used for SA)
# bad.s.13 	 0.0 		 0.75 		 0.25 	(used for SA)
# bad.s.14 	 0.0 		 0.75 		 0.25 	(used for SA)
# badly.r.05 	 0.125 		 0.25 		 0.625
# badly.r.06 	 0.125 		 0.25 		 0.625
#
# sentiment score of 'bad': -0.7916666666666666
# --------------------------------------------------
#
# target word:  school
# synset name	positive 	negative 	objective
# school.n.01 	 0.0 		 0.0 		 1.0
# school.n.02 	 0.0 		 0.0 		 1.0
# school.n.03 	 0.0 		 0.0 		 1.0
# school.n.04 	 0.0 		 0.0 		 1.0
# school.n.05 	 0.0 		 0.0 		 1.0
# school.n.06 	 0.0 		 0.0 		 1.0
# school.n.07 	 0.0 		 0.0 		 1.0
# school.v.01 	 0.0 		 0.0 		 1.0
# educate.v.03 	 0.375 		 0.125 		 0.5
# school.v.03 	 0.0 		 0.0 		 1.0
#
# sentiment score of 'school': 0.0
# --------------------------------------------------

# %%
print("\n")
print("#"*60)
print("location sentiment analysis...")

def senti_score(target_word, obj_threshold):
    synsets = swn.senti_synsets(target_word)
    senti_score_list = []
    print(f"\n\ttarget word: {target_word}")
    print('\t\tsynset name\tpositive \tnegative \tobjective')
    for ss in synsets:
        pos = ss.pos_score()
        neg = ss.neg_score()
        obj = ss.obj_score()
        if obj <= obj_threshold:
            print("\t\t", ss.synset.name(),"\t", pos, "\t\t", neg, "\t\t", obj, '\t(used for SA)')
            senti_score_list.append(pos-neg)
        else:
            print("\t\t", ss.synset.name(),"\t", pos, "\t\t", neg, "\t\t", obj)
    if len(senti_score_list) == 0:
        senti_score = 0.
    else:
        senti_score = np.mean(senti_score_list)
    
    print(f"\t sentiment score of '{target_word}': {senti_score}")
    return senti_score

query = 'london'
print("Query: ", query)

neighbor_words = []
for neighbor_word in w2v_model.wv.most_similar(positive=[query]):
    neighbor_words.append(neighbor_word[0])
print("K-neigbor words: ", neighbor_words)

neighbor_senti_scores = []
used_neighbor_list = []
for neighbor in neighbor_words:
    score = senti_score(neighbor, obj_threshold=0.5)
    if score != 0:
        used_neighbor_list.append(neighbor)
        neighbor_senti_scores.append(score)

print()
print("used neighbor words \t", used_neighbor_list)
print("sentiment score of each neighbor word \t", neighbor_senti_scores)

print(f"final sentiment score of '{query}': \t {np.mean(neighbor_senti_scores)}")
# Out:
# ############################################################
# location sentiment analysis...
# Query:  london
# K-neigbor words:  ['tellson', 'mail', 'busy', 'partner', 'worthy', 'orphan', 'plane', 'elderly', 'blind', 'arrive']
#
# 	target word: tellson
# 		synset name	positive 	negative 	objective
# 	 sentiment score of 'tellson': 0.0
#
# 	target word: mail
# 		synset name	positive 	negative 	objective
# 		 mail.n.01 	 0.0 		 0.0 		 1.0
# 		 mail.n.02 	 0.0 		 0.0 		 1.0
# 		 mail.n.03 	 0.0 		 0.0 		 1.0
# 		 mail.n.04 	 0.0 		 0.0 		 1.0
# 		 chain_mail.n.01 	 0.0 		 0.0 		 1.0
# 		 mail.v.01 	 0.0 		 0.0 		 1.0
# 		 mail.v.02 	 0.0 		 0.0 		 1.0
# 	 sentiment score of 'mail': 0.0
#
# 	target word: busy
# 		synset name	positive 	negative 	objective
# 		 busy.v.01 	 0.375 		 0.0 		 0.625
# 		 busy.a.01 	 0.375 		 0.0 		 0.625
# 		 busy.s.02 	 0.25 		 0.0 		 0.75
# 		 interfering.s.01 	 0.0 		 0.75 		 0.25 	(used for SA)
# 		 busy.s.04 	 0.375 		 0.25 		 0.375 	(used for SA)
# 		 busy.s.05 	 0.0 		 0.0 		 1.0
# 	 sentiment score of 'busy': -0.3125
#
# 	target word: partner
# 		synset name	positive 	negative 	objective
# 		 spouse.n.01 	 0.0 		 0.0 		 1.0
# 		 collaborator.n.03 	 0.0 		 0.0 		 1.0
# 		 partner.n.03 	 0.0 		 0.0 		 1.0
# 		 partner.v.01 	 0.0 		 0.0 		 1.0
# 		 partner.v.02 	 0.0 		 0.0 		 1.0
# 	 sentiment score of 'partner': 0.0
#
# 	target word: worthy
# 		synset name	positive 	negative 	objective
# 		 worthy.n.01 	 0.5 		 0.0 		 0.5 	(used for SA)
# 		 worthy.a.01 	 0.875 		 0.0 		 0.125 	(used for SA)
# 		 desirable.s.02 	 0.5 		 0.0 		 0.5 	(used for SA)
# 		 worthy.s.03 	 0.875 		 0.0 		 0.125 	(used for SA)
# 	 sentiment score of 'worthy': 0.6875
#
# 	target word: orphan
# 		synset name	positive 	negative 	objective
# 		 orphan.n.01 	 0.0 		 0.0 		 1.0
# 		 orphan.n.02 	 0.0 		 0.0 		 1.0
# 		 orphan.n.03 	 0.0 		 0.0 		 1.0
# 		 orphan.n.04 	 0.0 		 0.125 		 0.875
# 		 orphan.v.01 	 0.0 		 0.0 		 1.0
# 	 sentiment score of 'orphan': 0.0
#
# 	target word: plane
# 		synset name	positive 	negative 	objective
# 		 airplane.n.01 	 0.0 		 0.0 		 1.0
# 		 plane.n.02 	 0.0 		 0.0 		 1.0
# 		 plane.n.03 	 0.0 		 0.0 		 1.0
# 		 plane.n.04 	 0.0 		 0.0 		 1.0
# 		 plane.n.05 	 0.0 		 0.0 		 1.0
# 		 plane.v.01 	 0.0 		 0.0 		 1.0
# 		 plane.v.02 	 0.0 		 0.0 		 1.0
# 		 plane.v.03 	 0.0 		 0.0 		 1.0
# 		 flat.s.01 	 0.375 		 0.25 		 0.375 	(used for SA)
# 	 sentiment score of 'plane': 0.125
#
# 	target word: elderly
# 		synset name	positive 	negative 	objective
# 		 aged.n.01 	 0.0 		 0.0 		 1.0
# 		 aged.s.01 	 0.5 		 0.0 		 0.5 	(used for SA)
# 	 sentiment score of 'elderly': 0.5
#
# 	target word: blind
# 		synset name	positive 	negative 	objective
# 		 blind.n.01 	 0.0 		 0.0 		 1.0
# 		 blind.n.02 	 0.0 		 0.0 		 1.0
# 		 blind.n.03 	 0.0 		 0.0 		 1.0
# 		 subterfuge.n.01 	 0.0 		 0.25 		 0.75
# 		 blind.v.01 	 0.0 		 0.375 		 0.625
# 		 blind.v.02 	 0.0 		 0.375 		 0.625
# 		 blind.v.03 	 0.0 		 0.125 		 0.875
# 		 blind.a.01 	 0.0 		 0.0 		 1.0
# 		 blind.s.02 	 0.0 		 0.75 		 0.25 	(used for SA)
# 		 blind.s.03 	 0.0 		 0.5 		 0.5 	(used for SA)
# 	 sentiment score of 'blind': -0.625
#
# 	target word: arrive
# 		synset name	positive 	negative 	objective
# 		 arrive.v.01 	 0.0 		 0.0 		 1.0
# 		 arrive.v.02 	 0.0 		 0.0 		 1.0
# 	 sentiment score of 'arrive': 0.0
#
# used neighbor words 	 ['busy', 'worthy', 'plane', 'elderly', 'blind']
# sentiment score of each neighbor word 	 [-0.3125, 0.6875, 0.125, 0.5, -0.625]
# final sentiment score of 'london': 	 0.075

# %%
def location_sentiment_analysis(query, w2v_model, num_k, obj_threshold):
    print("Query: ", query)
    
    neighbor_words = []
    neighbor_distances = []
    for neighbor_word in w2v_model.wv.most_similar(positive=[query], topn=num_k):
        neighbor_words.append(neighbor_word[0])
        neighbor_distances.append(neighbor_word[1])
    print("K-neigbor words: ", neighbor_words)
    print("K-neigbor distances: ", neighbor_distances)
    
    neighbor_senti_scores = []
    used_neighbor_list = []
    for neighbor in neighbor_words:
        score = senti_score(neighbor, obj_threshold=obj_threshold)
        if score != 0:
            used_neighbor_list.append(neighbor)
            neighbor_senti_scores.append(score)    
    
    print()
    print("used neighbor words \t", used_neighbor_list)
    print("sentiment score of each neighbor word \t", neighbor_senti_scores)
    
    sentiment_score = np.mean(neighbor_senti_scores)
    print(f"final sentiment score of '{query}': \t {sentiment_score}")
    
    return query, neighbor_words, used_neighbor_list, sentiment_score

# %% [markdown]
# ## 7. Location Sentiment Analysis Results

# %%
print("\n")
print("#"*60)
location_sentiment_analysis(query='london', w2v_model=w2v_model, num_k=20, obj_threshold=0.5)
# Out:
# ############################################################
# Query:  london
# K-neigbor words:  ['tellson', 'mail', 'busy', 'partner', 'worthy', 'orphan', 'plane', 'elderly', 'blind', 'arrive', 'seventy', 'bank', 'lodging', 'year', 'tellson_s', 'harness', 'description', 'hay', 'occupation', 'peace']
# K-neigbor distances:  [0.2956874370574951, 0.25125938653945923, 0.24844637513160706, 0.24216477572917938, 0.2364470660686493, 0.21845492720603943, 0.21606044471263885, 0.20789942145347595, 0.2076665163040161, 0.20607450604438782, 0.20242592692375183, 0.20105814933776855, 0.19967180490493774, 0.19859161972999573, 0.19798478484153748, 0.19285878539085388, 0.19185477495193481, 0.18657512962818146, 0.18314382433891296, 0.18270191550254822]
#
# 	target word: tellson
# 		synset name	positive 	negative 	objective
# 	 sentiment score of 'tellson': 0.0
#
# 	target word: mail
# 		synset name	positive 	negative 	objective
# 		 mail.n.01 	 0.0 		 0.0 		 1.0
# 		 mail.n.02 	 0.0 		 0.0 		 1.0
# 		 mail.n.03 	 0.0 		 0.0 		 1.0
# 		 mail.n.04 	 0.0 		 0.0 		 1.0
# 		 chain_mail.n.01 	 0.0 		 0.0 		 1.0
# 		 mail.v.01 	 0.0 		 0.0 		 1.0
# 		 mail.v.02 	 0.0 		 0.0 		 1.0
# 	 sentiment score of 'mail': 0.0
#
# 	target word: busy
# 		synset name	positive 	negative 	objective
# 		 busy.v.01 	 0.375 		 0.0 		 0.625
# 		 busy.a.01 	 0.375 		 0.0 		 0.625
# 		 busy.s.02 	 0.25 		 0.0 		 0.75
# 		 interfering.s.01 	 0.0 		 0.75 		 0.25 	(used for SA)
# 		 busy.s.04 	 0.375 		 0.25 		 0.375 	(used for SA)
# 		 busy.s.05 	 0.0 		 0.0 		 1.0
# 	 sentiment score of 'busy': -0.3125
#
# 	target word: partner
# 		synset name	positive 	negative 	objective
# 		 spouse.n.01 	 0.0 		 0.0 		 1.0
# 		 collaborator.n.03 	 0.0 		 0.0 		 1.0
# 		 partner.n.03 	 0.0 		 0.0 		 1.0
# 		 partner.v.01 	 0.0 		 0.0 		 1.0
# 		 partner.v.02 	 0.0 		 0.0 		 1.0
# 	 sentiment score of 'partner': 0.0
#
# 	target word: worthy
# 		synset name	positive 	negative 	objective
# 		 worthy.n.01 	 0.5 		 0.0 		 0.5 	(used for SA)
# 		 worthy.a.01 	 0.875 		 0.0 		 0.125 	(used for SA)
# 		 desirable.s.02 	 0.5 		 0.0 		 0.5 	(used for SA)
# 		 worthy.s.03 	 0.875 		 0.0 		 0.125 	(used for SA)
# 	 sentiment score of 'worthy': 0.6875
#
# 	target word: orphan
# 		synset name	positive 	negative 	objective
# 		 orphan.n.01 	 0.0 		 0.0 		 1.0
# 		 orphan.n.02 	 0.0 		 0.0 		 1.0
# 		 orphan.n.03 	 0.0 		 0.0 		 1.0
# 		 orphan.n.04 	 0.0 		 0.125 		 0.875
# 		 orphan.v.01 	 0.0 		 0.0 		 1.0
# 	 sentiment score of 'orphan': 0.0
#
# 	target word: plane
# 		synset name	positive 	negative 	objective
# 		 airplane.n.01 	 0.0 		 0.0 		 1.0
# 		 plane.n.02 	 0.0 		 0.0 		 1.0
# 		 plane.n.03 	 0.0 		 0.0 		 1.0
# 		 plane.n.04 	 0.0 		 0.0 		 1.0
# 		 plane.n.05 	 0.0 		 0.0 		 1.0
# 		 plane.v.01 	 0.0 		 0.0 		 1.0
# 		 plane.v.02 	 0.0 		 0.0 		 1.0
# 		 plane.v.03 	 0.0 		 0.0 		 1.0
# 		 flat.s.01 	 0.375 		 0.25 		 0.375 	(used for SA)
# 	 sentiment score of 'plane': 0.125
#
# 	target word: elderly
# 		synset name	positive 	negative 	objective
# 		 aged.n.01 	 0.0 		 0.0 		 1.0
# 		 aged.s.01 	 0.5 		 0.0 		 0.5 	(used for SA)
# 	 sentiment score of 'elderly': 0.5
#
# 	target word: blind
# 		synset name	positive 	negative 	objective
# 		 blind.n.01 	 0.0 		 0.0 		 1.0
# 		 blind.n.02 	 0.0 		 0.0 		 1.0
# 		 blind.n.03 	 0.0 		 0.0 		 1.0
# 		 subterfuge.n.01 	 0.0 		 0.25 		 0.75
# 		 blind.v.01 	 0.0 		 0.375 		 0.625
# 		 blind.v.02 	 0.0 		 0.375 		 0.625
# 		 blind.v.03 	 0.0 		 0.125 		 0.875
# 		 blind.a.01 	 0.0 		 0.0 		 1.0
# 		 blind.s.02 	 0.0 		 0.75 		 0.25 	(used for SA)
# 		 blind.s.03 	 0.0 		 0.5 		 0.5 	(used for SA)
# 	 sentiment score of 'blind': -0.625
#
# 	target word: arrive
# 		synset name	positive 	negative 	objective
# 		 arrive.v.01 	 0.0 		 0.0 		 1.0
# 		 arrive.v.02 	 0.0 		 0.0 		 1.0
# 	 sentiment score of 'arrive': 0.0
#
# 	target word: seventy
# 		synset name	positive 	negative 	objective
# 		 seventy.n.01 	 0.0 		 0.0 		 1.0
# 		 seventy.s.01 	 0.0 		 0.0 		 1.0
# 	 sentiment score of 'seventy': 0.0
#
# 	target word: bank
# 		synset name	positive 	negative 	objective
# 		 bank.n.01 	 0.0 		 0.0 		 1.0
# 		 depository_financial_institution.n.01 	 0.0 		 0.0 		 1.0
# 		 bank.n.03 	 0.0 		 0.0 		 1.0
# 		 bank.n.04 	 0.0 		 0.0 		 1.0
# 		 bank.n.05 	 0.0 		 0.0 		 1.0
# 		 bank.n.06 	 0.0 		 0.0 		 1.0
# 		 bank.n.07 	 0.0 		 0.0 		 1.0
# 		 savings_bank.n.02 	 0.0 		 0.0 		 1.0
# 		 bank.n.09 	 0.0 		 0.0 		 1.0
# 		 bank.n.10 	 0.0 		 0.0 		 1.0
# 		 bank.v.01 	 0.0 		 0.0 		 1.0
# 		 bank.v.02 	 0.0 		 0.0 		 1.0
# 		 bank.v.03 	 0.0 		 0.0 		 1.0
# 		 bank.v.04 	 0.0 		 0.0 		 1.0
# 		 bank.v.05 	 0.0 		 0.0 		 1.0
# 		 deposit.v.02 	 0.0 		 0.0 		 1.0
# 		 bank.v.07 	 0.0 		 0.0 		 1.0
# 		 trust.v.01 	 0.375 		 0.0 		 0.625
# 	 sentiment score of 'bank': 0.0
#
# 	target word: lodging
# 		synset name	positive 	negative 	objective
# 		 housing.n.01 	 0.0 		 0.0 		 1.0
# 		 lodgment.n.02 	 0.125 		 0.125 		 0.75
# 		 lodging.n.03 	 0.0 		 0.0 		 1.0
# 		 lodge.v.01 	 0.0 		 0.0 		 1.0
# 		 lodge.v.02 	 0.0 		 0.0 		 1.0
# 		 charge.v.06 	 0.0 		 0.0 		 1.0
# 		 lodge.v.04 	 0.0 		 0.0 		 1.0
# 	 sentiment score of 'lodging': 0.0
#
# 	target word: year
# 		synset name	positive 	negative 	objective
# 		 year.n.01 	 0.0 		 0.0 		 1.0
# 		 year.n.02 	 0.0 		 0.0 		 1.0
# 		 year.n.03 	 0.0 		 0.0 		 1.0
# 		 class.n.06 	 0.0 		 0.0 		 1.0
# 	 sentiment score of 'year': 0.0
#
# 	target word: tellson_s
# 		synset name	positive 	negative 	objective
# 	 sentiment score of 'tellson_s': 0.0
#
# 	target word: harness
# 		synset name	positive 	negative 	objective
# 		 harness.n.01 	 0.0 		 0.0 		 1.0
# 		 harness.n.02 	 0.0 		 0.0 		 1.0
# 		 harness.v.01 	 0.0 		 0.0 		 1.0
# 		 harness.v.02 	 0.125 		 0.0 		 0.875
# 		 harness.v.03 	 0.0 		 0.0 		 1.0
# 		 rule.v.07 	 0.0 		 0.0 		 1.0
# 	 sentiment score of 'harness': 0.0
#
# 	target word: description
# 		synset name	positive 	negative 	objective
# 		 description.n.01 	 0.0 		 0.0 		 1.0
# 		 description.n.02 	 0.0 		 0.0 		 1.0
# 		 description.n.03 	 0.0 		 0.125 		 0.875
# 	 sentiment score of 'description': 0.0
#
# 	target word: hay
# 		synset name	positive 	negative 	objective
# 		 hay.n.01 	 0.0 		 0.0 		 1.0
# 		 hay.v.01 	 0.0 		 0.0 		 1.0
# 	 sentiment score of 'hay': 0.0
#
# 	target word: occupation
# 		synset name	positive 	negative 	objective
# 		 occupation.n.01 	 0.0 		 0.0 		 1.0
# 		 occupation.n.02 	 0.0 		 0.0 		 1.0
# 		 occupation.n.03 	 0.0 		 0.0 		 1.0
# 		 occupation.n.04 	 0.0 		 0.0 		 1.0
# 		 occupation.n.05 	 0.0 		 0.0 		 1.0
# 	 sentiment score of 'occupation': 0.0
#
# 	target word: peace
# 		synset name	positive 	negative 	objective
# 		 peace.n.01 	 0.125 		 0.0 		 0.875
# 		 peace.n.02 	 0.25 		 0.0 		 0.75
# 		 peace.n.03 	 0.125 		 0.5 		 0.375 	(used for SA)
# 		 peace.n.04 	 0.0 		 0.0 		 1.0
# 		 peace.n.05 	 0.0 		 0.0 		 1.0
# 	 sentiment score of 'peace': -0.375
#
# used neighbor words 	 ['busy', 'worthy', 'plane', 'elderly', 'blind', 'peace']
# sentiment score of each neighbor word 	 [-0.3125, 0.6875, 0.125, 0.5, -0.625, -0.375]
# final sentiment score of 'london': 	 0.0
# ('london',
#  ['tellson',
#   'mail',
#   'busy',
#   'partner',
#   'worthy',
#   'orphan',
#   'plane',
#   'elderly',
#   'blind',
#   'arrive',
#   'seventy',
#   'bank',
#   'lodging',
#   'year',
#   'tellson_s',
#   'harness',
#   'description',
#   'hay',
#   'occupation',
#   'peace'],
#  ['busy', 'worthy', 'plane', 'elderly', 'blind', 'peace'],
#  0.0)

# %%
print("\n")
print("#"*60)
location_sentiment_analysis(query='paris', w2v_model=w2v_model, num_k=20, obj_threshold=0.5)
# Out:
# ############################################################
# Query:  paris
# K-neigbor words:  ['journey', 'establish', 'busy', 'bank', 'country', 'overflow', 'destroy', 'mode', 'beauvais', 'despatch', 'communicate', 'day', 'keeper', 'shilling', 'road', 'travel', 'mount', 'deal', 'populace', 'slightly']
# K-neigbor distances:  [0.2842642366886139, 0.23648369312286377, 0.21542930603027344, 0.21482771635055542, 0.21150873601436615, 0.20536592602729797, 0.1969098150730133, 0.1966996192932129, 0.19505669176578522, 0.19394749402999878, 0.18605686724185944, 0.18340164422988892, 0.1772938221693039, 0.17596665024757385, 0.1745319813489914, 0.17398419976234436, 0.1736697405576706, 0.1722383052110672, 0.16972346603870392, 0.1663377285003662]
#
# 	target word: journey
# 		synset name	positive 	negative 	objective
# 		 journey.n.01 	 0.0 		 0.0 		 1.0
# 		 travel.v.02 	 0.0 		 0.0 		 1.0
# 		 travel.v.04 	 0.0 		 0.0 		 1.0
# 	 sentiment score of 'journey': 0.0
#
# 	target word: establish
# 		synset name	positive 	negative 	objective
# 		 establish.v.01 	 0.0 		 0.0 		 1.0
# 		 establish.v.02 	 0.0 		 0.0 		 1.0
# 		 prove.v.02 	 0.5 		 0.0 		 0.5 	(used for SA)
# 		 lay_down.v.01 	 0.0 		 0.0 		 1.0
# 		 establish.v.05 	 0.0 		 0.0 		 1.0
# 		 install.v.03 	 0.0 		 0.0 		 1.0
# 		 build.v.03 	 0.0 		 0.0 		 1.0
# 		 establish.v.08 	 0.0 		 0.0 		 1.0
# 	 sentiment score of 'establish': 0.5
#
# 	target word: busy
# 		synset name	positive 	negative 	objective
# 		 busy.v.01 	 0.375 		 0.0 		 0.625
# 		 busy.a.01 	 0.375 		 0.0 		 0.625
# 		 busy.s.02 	 0.25 		 0.0 		 0.75
# 		 interfering.s.01 	 0.0 		 0.75 		 0.25 	(used for SA)
# 		 busy.s.04 	 0.375 		 0.25 		 0.375 	(used for SA)
# 		 busy.s.05 	 0.0 		 0.0 		 1.0
# 	 sentiment score of 'busy': -0.3125
#
# 	target word: bank
# 		synset name	positive 	negative 	objective
# 		 bank.n.01 	 0.0 		 0.0 		 1.0
# 		 depository_financial_institution.n.01 	 0.0 		 0.0 		 1.0
# 		 bank.n.03 	 0.0 		 0.0 		 1.0
# 		 bank.n.04 	 0.0 		 0.0 		 1.0
# 		 bank.n.05 	 0.0 		 0.0 		 1.0
# 		 bank.n.06 	 0.0 		 0.0 		 1.0
# 		 bank.n.07 	 0.0 		 0.0 		 1.0
# 		 savings_bank.n.02 	 0.0 		 0.0 		 1.0
# 		 bank.n.09 	 0.0 		 0.0 		 1.0
# 		 bank.n.10 	 0.0 		 0.0 		 1.0
# 		 bank.v.01 	 0.0 		 0.0 		 1.0
# 		 bank.v.02 	 0.0 		 0.0 		 1.0
# 		 bank.v.03 	 0.0 		 0.0 		 1.0
# 		 bank.v.04 	 0.0 		 0.0 		 1.0
# 		 bank.v.05 	 0.0 		 0.0 		 1.0
# 		 deposit.v.02 	 0.0 		 0.0 		 1.0
# 		 bank.v.07 	 0.0 		 0.0 		 1.0
# 		 trust.v.01 	 0.375 		 0.0 		 0.625
# 	 sentiment score of 'bank': 0.0
#
# 	target word: country
# 		synset name	positive 	negative 	objective
# 		 state.n.04 	 0.0 		 0.0 		 1.0
# 		 country.n.02 	 0.0 		 0.0 		 1.0
# 		 nation.n.02 	 0.0 		 0.0 		 1.0
# 		 country.n.04 	 0.0 		 0.0 		 1.0
# 		 area.n.01 	 0.0 		 0.0 		 1.0
# 	 sentiment score of 'country': 0.0
#
# 	target word: overflow
# 		synset name	positive 	negative 	objective
# 		 flood.n.04 	 0.0 		 0.0 		 1.0
# 		 overflow.n.02 	 0.0 		 0.0 		 1.0
# 		 overflow.v.01 	 0.0 		 0.0 		 1.0
# 		 bubble_over.v.01 	 0.25 		 0.75 		 0.0 	(used for SA)
# 	 sentiment score of 'overflow': -0.5
#
# 	target word: destroy
# 		synset name	positive 	negative 	objective
# 		 destroy.v.01 	 0.0 		 0.0 		 1.0
# 		 destroy.v.02 	 0.0 		 0.5 		 0.5 	(used for SA)
# 		 demolish.v.03 	 0.125 		 0.0 		 0.875
# 		 destroy.v.04 	 0.0 		 0.25 		 0.75
# 	 sentiment score of 'destroy': -0.5
#
# 	target word: mode
# 		synset name	positive 	negative 	objective
# 		 manner.n.01 	 0.0 		 0.0 		 1.0
# 		 mode.n.02 	 0.0 		 0.0 		 1.0
# 		 modality.n.01 	 0.0 		 0.0 		 1.0
# 		 mood.n.03 	 0.0 		 0.0 		 1.0
# 		 mode.n.05 	 0.0 		 0.0 		 1.0
# 		 mode.n.06 	 0.0 		 0.0 		 1.0
# 	 sentiment score of 'mode': 0.0
#
# 	target word: beauvais
# 		synset name	positive 	negative 	objective
# 	 sentiment score of 'beauvais': 0.0
#
# 	target word: despatch
# 		synset name	positive 	negative 	objective
# 		 dispatch.n.01 	 0.0 		 0.0 		 1.0
# 		 dispatch.n.03 	 0.0 		 0.0 		 1.0
# 		 dispatch.n.04 	 0.0 		 0.0 		 1.0
# 		 dispatch.n.02 	 0.0 		 0.0 		 1.0
# 		 dispatch.v.01 	 0.0 		 0.0 		 1.0
# 	 sentiment score of 'despatch': 0.0
#
# 	target word: communicate
# 		synset name	positive 	negative 	objective
# 		 communicate.v.01 	 0.0 		 0.0 		 1.0
# 		 communicate.v.02 	 0.0 		 0.125 		 0.875
# 		 convey.v.03 	 0.0 		 0.0 		 1.0
# 		 communicate.v.04 	 0.0 		 0.0 		 1.0
# 		 communicate.v.05 	 0.0 		 0.0 		 1.0
# 		 communicate.v.06 	 0.0 		 0.0 		 1.0
# 		 commune.v.02 	 0.0 		 0.0 		 1.0
# 	 sentiment score of 'communicate': 0.0
#
# 	target word: day
# 		synset name	positive 	negative 	objective
# 		 day.n.01 	 0.0 		 0.0 		 1.0
# 		 day.n.02 	 0.125 		 0.0 		 0.875
# 		 day.n.03 	 0.0 		 0.0 		 1.0
# 		 day.n.04 	 0.0 		 0.0 		 1.0
# 		 day.n.05 	 0.0 		 0.0 		 1.0
# 		 day.n.06 	 0.125 		 0.0 		 0.875
# 		 day.n.07 	 0.0 		 0.0 		 1.0
# 		 sidereal_day.n.01 	 0.0 		 0.0 		 1.0
# 		 day.n.09 	 0.25 		 0.0 		 0.75
# 		 day.n.10 	 0.0 		 0.0 		 1.0
# 	 sentiment score of 'day': 0.0
#
# 	target word: keeper
# 		synset name	positive 	negative 	objective
# 		 keeper.n.01 	 0.0 		 0.0 		 1.0
# 		 custodian.n.01 	 0.0 		 0.0 		 1.0
# 	 sentiment score of 'keeper': 0.0
#
# 	target word: shilling
# 		synset name	positive 	negative 	objective
# 		 ugandan_shilling.n.01 	 0.0 		 0.0 		 1.0
# 		 tanzanian_shilling.n.01 	 0.0 		 0.0 		 1.0
# 		 somalian_shilling.n.01 	 0.0 		 0.0 		 1.0
# 		 kenyan_shilling.n.01 	 0.0 		 0.0 		 1.0
# 		 british_shilling.n.01 	 0.0 		 0.0 		 1.0
# 		 shilling.n.06 	 0.0 		 0.0 		 1.0
# 		 shill.v.01 	 0.0 		 0.0 		 1.0
# 	 sentiment score of 'shilling': 0.0
#
# 	target word: road
# 		synset name	positive 	negative 	objective
# 		 road.n.01 	 0.0 		 0.0 		 1.0
# 		 road.n.02 	 0.0 		 0.0 		 1.0
# 	 sentiment score of 'road': 0.0
#
# 	target word: travel
# 		synset name	positive 	negative 	objective
# 		 travel.n.01 	 0.0 		 0.0 		 1.0
# 		 change_of_location.n.01 	 0.0 		 0.0 		 1.0
# 		 locomotion.n.02 	 0.0 		 0.0 		 1.0
# 		 travel.v.01 	 0.0 		 0.0 		 1.0
# 		 travel.v.02 	 0.0 		 0.0 		 1.0
# 		 travel.v.03 	 0.0 		 0.0 		 1.0
# 		 travel.v.04 	 0.0 		 0.0 		 1.0
# 		 travel.v.05 	 0.0 		 0.0 		 1.0
# 		 travel.v.06 	 0.0 		 0.0 		 1.0
# 	 sentiment score of 'travel': 0.0
#
# 	target word: mount
# 		synset name	positive 	negative 	objective
# 		 saddle_horse.n.01 	 0.0 		 0.0 		 1.0
# 		 climb.n.03 	 0.0 		 0.0 		 1.0
# 		 mountain.n.01 	 0.0 		 0.0 		 1.0
# 		 mount.n.04 	 0.0 		 0.0 		 1.0
# 		 backing.n.02 	 0.0 		 0.0 		 1.0
# 		 mount.v.01 	 0.0 		 0.0 		 1.0
# 		 wax.v.02 	 0.0 		 0.0 		 1.0
# 		 mount.v.03 	 0.0 		 0.0 		 1.0
# 		 mount.v.04 	 0.0 		 0.0 		 1.0
# 		 hop_on.v.01 	 0.0 		 0.0 		 1.0
# 		 climb.v.01 	 0.0 		 0.0 		 1.0
# 		 mount.v.07 	 0.0 		 0.0 		 1.0
# 		 ride.v.14 	 0.0 		 0.0 		 1.0
# 	 sentiment score of 'mount': 0.0
#
# 	target word: deal
# 		synset name	positive 	negative 	objective
# 		 deal.n.01 	 0.0 		 0.0 		 1.0
# 		 bargain.n.01 	 0.0 		 0.0 		 1.0
# 		 batch.n.02 	 0.0 		 0.0 		 1.0
# 		 deal.n.04 	 0.0 		 0.0 		 1.0
# 		 softwood.n.01 	 0.0 		 0.0 		 1.0
# 		 hand.n.06 	 0.0 		 0.0 		 1.0
# 		 deal.n.07 	 0.0 		 0.0 		 1.0
# 		 deal.n.08 	 0.0 		 0.0 		 1.0
# 		 deal.n.09 	 0.0 		 0.0 		 1.0
# 		 cover.v.05 	 0.0 		 0.0 		 1.0
# 		 consider.v.03 	 0.0 		 0.0 		 1.0
# 		 deal.v.03 	 0.0 		 0.0 		 1.0
# 		 cope.v.01 	 0.0 		 0.0 		 1.0
# 		 distribute.v.01 	 0.0 		 0.0 		 1.0
# 		 deal.v.06 	 0.0 		 0.0 		 1.0
# 		 manage.v.02 	 0.0 		 0.0 		 1.0
# 		 deal.v.08 	 0.0 		 0.0 		 1.0
# 		 deal.v.09 	 0.0 		 0.0 		 1.0
# 		 conduct.v.01 	 0.0 		 0.0 		 1.0
# 		 share.v.04 	 0.0 		 0.0 		 1.0
# 		 deal.v.12 	 0.0 		 0.0 		 1.0
# 		 deal.v.13 	 0.0 		 0.0 		 1.0
# 	 sentiment score of 'deal': 0.0
#
# 	target word: populace
# 		synset name	positive 	negative 	objective
# 		 populace.n.01 	 0.0 		 0.0 		 1.0
# 	 sentiment score of 'populace': 0.0
#
# 	target word: slightly
# 		synset name	positive 	negative 	objective
# 		 slightly.r.01 	 0.0 		 0.0 		 1.0
# 		 slenderly.r.01 	 0.25 		 0.0 		 0.75
# 	 sentiment score of 'slightly': 0.0
#
# used neighbor words 	 ['establish', 'busy', 'overflow', 'destroy']
# sentiment score of each neighbor word 	 [0.5, -0.3125, -0.5, -0.5]
# final sentiment score of 'paris': 	 -0.203125
# ('paris',
#  ['journey',
#   'establish',
#   'busy',
#   'bank',
#   'country',
#   'overflow',
#   'destroy',
#   'mode',
#   'beauvais',
#   'despatch',
#   'communicate',
#   'day',
#   'keeper',
#   'shilling',
#   'road',
#   'travel',
#   'mount',
#   'deal',
#   'populace',
#   'slightly'],
#  ['establish', 'busy', 'overflow', 'destroy'],
#  -0.203125)

# %% [markdown]
# ## 8. Visualization

# %%
# 1) Query(red) / 2) Neighbor(blue) / 3) used Neighbor(green) / 4)ohter words(purple) 

def scatterplot(model, query, neighbor_words, used_neighbor_list, other_words_list=None, method='pca'):
    """ Plot in seaborn the results from the t-SNE dimensionality reduction algorithm of the vectors of a query word,
    its list of most similar words, and a list of words.
    """
    arrays = np.empty((0, 300), dtype='f')
    word_labels = [query]
    color_list  = ['red']
    

    # adds the vector of the query word
    arrays = np.append(arrays, model.wv.__getitem__([query]), axis=0)
    
    # adds the vector for each of the closest words to the array
    for neighbor in neighbor_words:
        wrd_vector = model.wv.__getitem__([neighbor])
        word_labels.append(neighbor)
        if neighbor in used_neighbor_list:
            color_list.append('green')
        else:
            color_list.append('blue')
        arrays = np.append(arrays, wrd_vector, axis=0)
        
    # adds the vector for each of the closest words to the array
    #for used_neighbor in used_neighbor_list:
    #    wrd_vector = model.wv.__getitem__([used_neighbor])
    #    word_labels.append(used_neighbor)
    #    color_list.append('green')
    #    arrays = np.append(arrays, wrd_vector, axis=0)
    
    # adds the vector for each of the words from list_names to the array
    if other_words_list != None:
        for wrd in other_words_list:
            wrd_vector = model.wv.__getitem__([wrd])
            word_labels.append(wrd)
            color_list.append('purple')
            arrays = np.append(arrays, wrd_vector, axis=0)
        
    # Reduces the dimensionality from 300 to 50 dimensions with PCA
    if method == 'pca':
        Y = PCA(n_components=2).fit_transform(arrays)
    elif method == 'tsne':
        # Finds t-SNE coordinates for 2 dimensions
        np.set_printoptions(suppress=True)
        Y = TSNE(n_components=2, random_state=0, perplexity=15).fit_transform(arrays)
    
    # Sets everything up to plot
    df = pd.DataFrame({'x': [x for x in Y[:, 0]],
                       'y': [y for y in Y[:, 1]],
                       'words': word_labels,
                       'color': color_list})
    
    fig, _ = plt.subplots()
    fig.set_size_inches(20, 20)
    
    # Basic plot
    p1 = sns.regplot(data=df,
                     x="x",
                     y="y",
                     fit_reg=False,
                     marker="o",
                     scatter_kws={'s': 40,
                                  'facecolors': df['color']
                                 }
                    )
    
    # Adds annotations one by one with a loop
    for line in range(0, df.shape[0]):
        
        p1.text(df["x"][line],
                df['y'][line],
                '  ' + df["words"][line].title(),
                horizontalalignment='left',
                verticalalignment='bottom', size='medium',
                color=df['color'][line],
                weight='normal'
                ).set_size(25)

    extra_size = 2
    plt.xlim(Y[:, 0].min()-extra_size, Y[:, 0].max()+extra_size)
    plt.ylim(Y[:, 1].min()-extra_size, Y[:, 1].max()+extra_size)
            
    plt.title('{} visualization for "{}"'.format(method, query))

# %%
print("\n")
print("#"*60)
query = 'london'
results = location_sentiment_analysis(query=query, w2v_model=w2v_model, num_k=20, obj_threshold=0.5)
query, neighbor_words, used_neighbor_list, sentiment_score = results

print()
scatterplot(w2v_model, query, neighbor_words, used_neighbor_list, other_words_list=['paris', 'england', 'france'])
# Out:
# ############################################################
# Query:  london
# K-neigbor words:  ['tellson', 'mail', 'busy', 'partner', 'worthy', 'orphan', 'plane', 'elderly', 'blind', 'arrive', 'seventy', 'bank', 'lodging', 'year', 'tellson_s', 'harness', 'description', 'hay', 'occupation', 'peace']
# K-neigbor distances:  [0.2956874370574951, 0.25125938653945923, 0.24844637513160706, 0.24216477572917938, 0.2364470660686493, 0.21845492720603943, 0.21606044471263885, 0.20789942145347595, 0.2076665163040161, 0.20607450604438782, 0.20242592692375183, 0.20105814933776855, 0.19967180490493774, 0.19859161972999573, 0.19798478484153748, 0.19285878539085388, 0.19185477495193481, 0.18657512962818146, 0.18314382433891296, 0.18270191550254822]
#
# 	target word: tellson
# 		synset name	positive 	negative 	objective
# 	 sentiment score of 'tellson': 0.0
#
# 	target word: mail
# 		synset name	positive 	negative 	objective
# 		 mail.n.01 	 0.0 		 0.0 		 1.0
# 		 mail.n.02 	 0.0 		 0.0 		 1.0
# 		 mail.n.03 	 0.0 		 0.0 		 1.0
# 		 mail.n.04 	 0.0 		 0.0 		 1.0
# 		 chain_mail.n.01 	 0.0 		 0.0 		 1.0
# 		 mail.v.01 	 0.0 		 0.0 		 1.0
# 		 mail.v.02 	 0.0 		 0.0 		 1.0
# 	 sentiment score of 'mail': 0.0
#
# 	target word: busy
# 		synset name	positive 	negative 	objective
# 		 busy.v.01 	 0.375 		 0.0 		 0.625
# 		 busy.a.01 	 0.375 		 0.0 		 0.625
# 		 busy.s.02 	 0.25 		 0.0 		 0.75
# 		 interfering.s.01 	 0.0 		 0.75 		 0.25 	(used for SA)
# 		 busy.s.04 	 0.375 		 0.25 		 0.375 	(used for SA)
# 		 busy.s.05 	 0.0 		 0.0 		 1.0
# 	 sentiment score of 'busy': -0.3125
#
# 	target word: partner
# 		synset name	positive 	negative 	objective
# 		 spouse.n.01 	 0.0 		 0.0 		 1.0
# 		 collaborator.n.03 	 0.0 		 0.0 		 1.0
# 		 partner.n.03 	 0.0 		 0.0 		 1.0
# 		 partner.v.01 	 0.0 		 0.0 		 1.0
# 		 partner.v.02 	 0.0 		 0.0 		 1.0
# 	 sentiment score of 'partner': 0.0
#
# 	target word: worthy
# 		synset name	positive 	negative 	objective
# 		 worthy.n.01 	 0.5 		 0.0 		 0.5 	(used for SA)
# 		 worthy.a.01 	 0.875 		 0.0 		 0.125 	(used for SA)
# 		 desirable.s.02 	 0.5 		 0.0 		 0.5 	(used for SA)
# 		 worthy.s.03 	 0.875 		 0.0 		 0.125 	(used for SA)
# 	 sentiment score of 'worthy': 0.6875
#
# 	target word: orphan
# 		synset name	positive 	negative 	objective
# 		 orphan.n.01 	 0.0 		 0.0 		 1.0
# 		 orphan.n.02 	 0.0 		 0.0 		 1.0
# 		 orphan.n.03 	 0.0 		 0.0 		 1.0
# 		 orphan.n.04 	 0.0 		 0.125 		 0.875
# 		 orphan.v.01 	 0.0 		 0.0 		 1.0
# 	 sentiment score of 'orphan': 0.0
#
# 	target word: plane
# 		synset name	positive 	negative 	objective
# 		 airplane.n.01 	 0.0 		 0.0 		 1.0
# 		 plane.n.02 	 0.0 		 0.0 		 1.0
# 		 plane.n.03 	 0.0 		 0.0 		 1.0
# 		 plane.n.04 	 0.0 		 0.0 		 1.0
# 		 plane.n.05 	 0.0 		 0.0 		 1.0
# 		 plane.v.01 	 0.0 		 0.0 		 1.0
# 		 plane.v.02 	 0.0 		 0.0 		 1.0
# 		 plane.v.03 	 0.0 		 0.0 		 1.0
# 		 flat.s.01 	 0.375 		 0.25 		 0.375 	(used for SA)
# 	 sentiment score of 'plane': 0.125
#
# 	target word: elderly
# 		synset name	positive 	negative 	objective
# 		 aged.n.01 	 0.0 		 0.0 		 1.0
# 		 aged.s.01 	 0.5 		 0.0 		 0.5 	(used for SA)
# 	 sentiment score of 'elderly': 0.5
#
# 	target word: blind
# 		synset name	positive 	negative 	objective
# 		 blind.n.01 	 0.0 		 0.0 		 1.0
# 		 blind.n.02 	 0.0 		 0.0 		 1.0
# 		 blind.n.03 	 0.0 		 0.0 		 1.0
# 		 subterfuge.n.01 	 0.0 		 0.25 		 0.75
# 		 blind.v.01 	 0.0 		 0.375 		 0.625
# 		 blind.v.02 	 0.0 		 0.375 		 0.625
# 		 blind.v.03 	 0.0 		 0.125 		 0.875
# 		 blind.a.01 	 0.0 		 0.0 		 1.0
# 		 blind.s.02 	 0.0 		 0.75 		 0.25 	(used for SA)
# 		 blind.s.03 	 0.0 		 0.5 		 0.5 	(used for SA)
# 	 sentiment score of 'blind': -0.625
#
# 	target word: arrive
# 		synset name	positive 	negative 	objective
# 		 arrive.v.01 	 0.0 		 0.0 		 1.0
# 		 arrive.v.02 	 0.0 		 0.0 		 1.0
# 	 sentiment score of 'arrive': 0.0
#
# 	target word: seventy
# 		synset name	positive 	negative 	objective
# 		 seventy.n.01 	 0.0 		 0.0 		 1.0
# 		 seventy.s.01 	 0.0 		 0.0 		 1.0
# 	 sentiment score of 'seventy': 0.0
#
# 	target word: bank
# 		synset name	positive 	negative 	objective
# 		 bank.n.01 	 0.0 		 0.0 		 1.0
# 		 depository_financial_institution.n.01 	 0.0 		 0.0 		 1.0
# 		 bank.n.03 	 0.0 		 0.0 		 1.0
# 		 bank.n.04 	 0.0 		 0.0 		 1.0
# 		 bank.n.05 	 0.0 		 0.0 		 1.0
# 		 bank.n.06 	 0.0 		 0.0 		 1.0
# 		 bank.n.07 	 0.0 		 0.0 		 1.0
# 		 savings_bank.n.02 	 0.0 		 0.0 		 1.0
# 		 bank.n.09 	 0.0 		 0.0 		 1.0
# 		 bank.n.10 	 0.0 		 0.0 		 1.0
# 		 bank.v.01 	 0.0 		 0.0 		 1.0
# 		 bank.v.02 	 0.0 		 0.0 		 1.0
# 		 bank.v.03 	 0.0 		 0.0 		 1.0
# 		 bank.v.04 	 0.0 		 0.0 		 1.0
# 		 bank.v.05 	 0.0 		 0.0 		 1.0
# 		 deposit.v.02 	 0.0 		 0.0 		 1.0
# 		 bank.v.07 	 0.0 		 0.0 		 1.0
# 		 trust.v.01 	 0.375 		 0.0 		 0.625
# 	 sentiment score of 'bank': 0.0
#
# 	target word: lodging
# 		synset name	positive 	negative 	objective
# 		 housing.n.01 	 0.0 		 0.0 		 1.0
# 		 lodgment.n.02 	 0.125 		 0.125 		 0.75
# 		 lodging.n.03 	 0.0 		 0.0 		 1.0
# 		 lodge.v.01 	 0.0 		 0.0 		 1.0
# 		 lodge.v.02 	 0.0 		 0.0 		 1.0
# 		 charge.v.06 	 0.0 		 0.0 		 1.0
# 		 lodge.v.04 	 0.0 		 0.0 		 1.0
# 	 sentiment score of 'lodging': 0.0
#
# 	target word: year
# 		synset name	positive 	negative 	objective
# 		 year.n.01 	 0.0 		 0.0 		 1.0
# 		 year.n.02 	 0.0 		 0.0 		 1.0
# 		 year.n.03 	 0.0 		 0.0 		 1.0
# 		 class.n.06 	 0.0 		 0.0 		 1.0
# 	 sentiment score of 'year': 0.0
#
# 	target word: tellson_s
# 		synset name	positive 	negative 	objective
# 	 sentiment score of 'tellson_s': 0.0
#
# 	target word: harness
# 		synset name	positive 	negative 	objective
# 		 harness.n.01 	 0.0 		 0.0 		 1.0
# 		 harness.n.02 	 0.0 		 0.0 		 1.0
# 		 harness.v.01 	 0.0 		 0.0 		 1.0
# 		 harness.v.02 	 0.125 		 0.0 		 0.875
# 		 harness.v.03 	 0.0 		 0.0 		 1.0
# 		 rule.v.07 	 0.0 		 0.0 		 1.0
# 	 sentiment score of 'harness': 0.0
#
# 	target word: description
# 		synset name	positive 	negative 	objective
# 		 description.n.01 	 0.0 		 0.0 		 1.0
# 		 description.n.02 	 0.0 		 0.0 		 1.0
# 		 description.n.03 	 0.0 		 0.125 		 0.875
# 	 sentiment score of 'description': 0.0
#
# 	target word: hay
# 		synset name	positive 	negative 	objective
# 		 hay.n.01 	 0.0 		 0.0 		 1.0
# 		 hay.v.01 	 0.0 		 0.0 		 1.0
# 	 sentiment score of 'hay': 0.0
#
# 	target word: occupation
# 		synset name	positive 	negative 	objective
# 		 occupation.n.01 	 0.0 		 0.0 		 1.0
# 		 occupation.n.02 	 0.0 		 0.0 		 1.0
# 		 occupation.n.03 	 0.0 		 0.0 		 1.0
# 		 occupation.n.04 	 0.0 		 0.0 		 1.0
# 		 occupation.n.05 	 0.0 		 0.0 		 1.0
# 	 sentiment score of 'occupation': 0.0
#
# 	target word: peace
# 		synset name	positive 	negative 	objective
# 		 peace.n.01 	 0.125 		 0.0 		 0.875
# 		 peace.n.02 	 0.25 		 0.0 		 0.75
# 		 peace.n.03 	 0.125 		 0.5 		 0.375 	(used for SA)
# 		 peace.n.04 	 0.0 		 0.0 		 1.0
# 		 peace.n.05 	 0.0 		 0.0 		 1.0
# 	 sentiment score of 'peace': -0.375
#
# used neighbor words 	 ['busy', 'worthy', 'plane', 'elderly', 'blind', 'peace']
# sentiment score of each neighbor word 	 [-0.3125, 0.6875, 0.125, 0.5, -0.625, -0.375]
# final sentiment score of 'london': 	 0.0

# %%
print("\n")
print("#"*60)
query = 'paris'
results = location_sentiment_analysis(query=query, w2v_model=w2v_model, num_k=20, obj_threshold=0.5)
query, neighbor_words, used_neighbor_list, sentiment_score = results

print()
scatterplot(w2v_model, query, neighbor_words, used_neighbor_list, other_words_list=['london', 'england', 'france'])
# Out:
# ############################################################
# Query:  paris
# K-neigbor words:  ['journey', 'establish', 'busy', 'bank', 'country', 'overflow', 'destroy', 'mode', 'beauvais', 'despatch', 'communicate', 'day', 'keeper', 'shilling', 'road', 'travel', 'mount', 'deal', 'populace', 'slightly']
# K-neigbor distances:  [0.2842642366886139, 0.23648369312286377, 0.21542930603027344, 0.21482771635055542, 0.21150873601436615, 0.20536592602729797, 0.1969098150730133, 0.1966996192932129, 0.19505669176578522, 0.19394749402999878, 0.18605686724185944, 0.18340164422988892, 0.1772938221693039, 0.17596665024757385, 0.1745319813489914, 0.17398419976234436, 0.1736697405576706, 0.1722383052110672, 0.16972346603870392, 0.1663377285003662]
#
# 	target word: journey
# 		synset name	positive 	negative 	objective
# 		 journey.n.01 	 0.0 		 0.0 		 1.0
# 		 travel.v.02 	 0.0 		 0.0 		 1.0
# 		 travel.v.04 	 0.0 		 0.0 		 1.0
# 	 sentiment score of 'journey': 0.0
#
# 	target word: establish
# 		synset name	positive 	negative 	objective
# 		 establish.v.01 	 0.0 		 0.0 		 1.0
# 		 establish.v.02 	 0.0 		 0.0 		 1.0
# 		 prove.v.02 	 0.5 		 0.0 		 0.5 	(used for SA)
# 		 lay_down.v.01 	 0.0 		 0.0 		 1.0
# 		 establish.v.05 	 0.0 		 0.0 		 1.0
# 		 install.v.03 	 0.0 		 0.0 		 1.0
# 		 build.v.03 	 0.0 		 0.0 		 1.0
# 		 establish.v.08 	 0.0 		 0.0 		 1.0
# 	 sentiment score of 'establish': 0.5
#
# 	target word: busy
# 		synset name	positive 	negative 	objective
# 		 busy.v.01 	 0.375 		 0.0 		 0.625
# 		 busy.a.01 	 0.375 		 0.0 		 0.625
# 		 busy.s.02 	 0.25 		 0.0 		 0.75
# 		 interfering.s.01 	 0.0 		 0.75 		 0.25 	(used for SA)
# 		 busy.s.04 	 0.375 		 0.25 		 0.375 	(used for SA)
# 		 busy.s.05 	 0.0 		 0.0 		 1.0
# 	 sentiment score of 'busy': -0.3125
#
# 	target word: bank
# 		synset name	positive 	negative 	objective
# 		 bank.n.01 	 0.0 		 0.0 		 1.0
# 		 depository_financial_institution.n.01 	 0.0 		 0.0 		 1.0
# 		 bank.n.03 	 0.0 		 0.0 		 1.0
# 		 bank.n.04 	 0.0 		 0.0 		 1.0
# 		 bank.n.05 	 0.0 		 0.0 		 1.0
# 		 bank.n.06 	 0.0 		 0.0 		 1.0
# 		 bank.n.07 	 0.0 		 0.0 		 1.0
# 		 savings_bank.n.02 	 0.0 		 0.0 		 1.0
# 		 bank.n.09 	 0.0 		 0.0 		 1.0
# 		 bank.n.10 	 0.0 		 0.0 		 1.0
# 		 bank.v.01 	 0.0 		 0.0 		 1.0
# 		 bank.v.02 	 0.0 		 0.0 		 1.0
# 		 bank.v.03 	 0.0 		 0.0 		 1.0
# 		 bank.v.04 	 0.0 		 0.0 		 1.0
# 		 bank.v.05 	 0.0 		 0.0 		 1.0
# 		 deposit.v.02 	 0.0 		 0.0 		 1.0
# 		 bank.v.07 	 0.0 		 0.0 		 1.0
# 		 trust.v.01 	 0.375 		 0.0 		 0.625
# 	 sentiment score of 'bank': 0.0
#
# 	target word: country
# 		synset name	positive 	negative 	objective
# 		 state.n.04 	 0.0 		 0.0 		 1.0
# 		 country.n.02 	 0.0 		 0.0 		 1.0
# 		 nation.n.02 	 0.0 		 0.0 		 1.0
# 		 country.n.04 	 0.0 		 0.0 		 1.0
# 		 area.n.01 	 0.0 		 0.0 		 1.0
# 	 sentiment score of 'country': 0.0
#
# 	target word: overflow
# 		synset name	positive 	negative 	objective
# 		 flood.n.04 	 0.0 		 0.0 		 1.0
# 		 overflow.n.02 	 0.0 		 0.0 		 1.0
# 		 overflow.v.01 	 0.0 		 0.0 		 1.0
# 		 bubble_over.v.01 	 0.25 		 0.75 		 0.0 	(used for SA)
# 	 sentiment score of 'overflow': -0.5
#
# 	target word: destroy
# 		synset name	positive 	negative 	objective
# 		 destroy.v.01 	 0.0 		 0.0 		 1.0
# 		 destroy.v.02 	 0.0 		 0.5 		 0.5 	(used for SA)
# 		 demolish.v.03 	 0.125 		 0.0 		 0.875
# 		 destroy.v.04 	 0.0 		 0.25 		 0.75
# 	 sentiment score of 'destroy': -0.5
#
# 	target word: mode
# 		synset name	positive 	negative 	objective
# 		 manner.n.01 	 0.0 		 0.0 		 1.0
# 		 mode.n.02 	 0.0 		 0.0 		 1.0
# 		 modality.n.01 	 0.0 		 0.0 		 1.0
# 		 mood.n.03 	 0.0 		 0.0 		 1.0
# 		 mode.n.05 	 0.0 		 0.0 		 1.0
# 		 mode.n.06 	 0.0 		 0.0 		 1.0
# 	 sentiment score of 'mode': 0.0
#
# 	target word: beauvais
# 		synset name	positive 	negative 	objective
# 	 sentiment score of 'beauvais': 0.0
#
# 	target word: despatch
# 		synset name	positive 	negative 	objective
# 		 dispatch.n.01 	 0.0 		 0.0 		 1.0
# 		 dispatch.n.03 	 0.0 		 0.0 		 1.0
# 		 dispatch.n.04 	 0.0 		 0.0 		 1.0
# 		 dispatch.n.02 	 0.0 		 0.0 		 1.0
# 		 dispatch.v.01 	 0.0 		 0.0 		 1.0
# 	 sentiment score of 'despatch': 0.0
#
# 	target word: communicate
# 		synset name	positive 	negative 	objective
# 		 communicate.v.01 	 0.0 		 0.0 		 1.0
# 		 communicate.v.02 	 0.0 		 0.125 		 0.875
# 		 convey.v.03 	 0.0 		 0.0 		 1.0
# 		 communicate.v.04 	 0.0 		 0.0 		 1.0
# 		 communicate.v.05 	 0.0 		 0.0 		 1.0
# 		 communicate.v.06 	 0.0 		 0.0 		 1.0
# 		 commune.v.02 	 0.0 		 0.0 		 1.0
# 	 sentiment score of 'communicate': 0.0
#
# 	target word: day
# 		synset name	positive 	negative 	objective
# 		 day.n.01 	 0.0 		 0.0 		 1.0
# 		 day.n.02 	 0.125 		 0.0 		 0.875
# 		 day.n.03 	 0.0 		 0.0 		 1.0
# 		 day.n.04 	 0.0 		 0.0 		 1.0
# 		 day.n.05 	 0.0 		 0.0 		 1.0
# 		 day.n.06 	 0.125 		 0.0 		 0.875
# 		 day.n.07 	 0.0 		 0.0 		 1.0
# 		 sidereal_day.n.01 	 0.0 		 0.0 		 1.0
# 		 day.n.09 	 0.25 		 0.0 		 0.75
# 		 day.n.10 	 0.0 		 0.0 		 1.0
# 	 sentiment score of 'day': 0.0
#
# 	target word: keeper
# 		synset name	positive 	negative 	objective
# 		 keeper.n.01 	 0.0 		 0.0 		 1.0
# 		 custodian.n.01 	 0.0 		 0.0 		 1.0
# 	 sentiment score of 'keeper': 0.0
#
# 	target word: shilling
# 		synset name	positive 	negative 	objective
# 		 ugandan_shilling.n.01 	 0.0 		 0.0 		 1.0
# 		 tanzanian_shilling.n.01 	 0.0 		 0.0 		 1.0
# 		 somalian_shilling.n.01 	 0.0 		 0.0 		 1.0
# 		 kenyan_shilling.n.01 	 0.0 		 0.0 		 1.0
# 		 british_shilling.n.01 	 0.0 		 0.0 		 1.0
# 		 shilling.n.06 	 0.0 		 0.0 		 1.0
# 		 shill.v.01 	 0.0 		 0.0 		 1.0
# 	 sentiment score of 'shilling': 0.0
#
# 	target word: road
# 		synset name	positive 	negative 	objective
# 		 road.n.01 	 0.0 		 0.0 		 1.0
# 		 road.n.02 	 0.0 		 0.0 		 1.0
# 	 sentiment score of 'road': 0.0
#
# 	target word: travel
# 		synset name	positive 	negative 	objective
# 		 travel.n.01 	 0.0 		 0.0 		 1.0
# 		 change_of_location.n.01 	 0.0 		 0.0 		 1.0
# 		 locomotion.n.02 	 0.0 		 0.0 		 1.0
# 		 travel.v.01 	 0.0 		 0.0 		 1.0
# 		 travel.v.02 	 0.0 		 0.0 		 1.0
# 		 travel.v.03 	 0.0 		 0.0 		 1.0
# 		 travel.v.04 	 0.0 		 0.0 		 1.0
# 		 travel.v.05 	 0.0 		 0.0 		 1.0
# 		 travel.v.06 	 0.0 		 0.0 		 1.0
# 	 sentiment score of 'travel': 0.0
#
# 	target word: mount
# 		synset name	positive 	negative 	objective
# 		 saddle_horse.n.01 	 0.0 		 0.0 		 1.0
# 		 climb.n.03 	 0.0 		 0.0 		 1.0
# 		 mountain.n.01 	 0.0 		 0.0 		 1.0
# 		 mount.n.04 	 0.0 		 0.0 		 1.0
# 		 backing.n.02 	 0.0 		 0.0 		 1.0
# 		 mount.v.01 	 0.0 		 0.0 		 1.0
# 		 wax.v.02 	 0.0 		 0.0 		 1.0
# 		 mount.v.03 	 0.0 		 0.0 		 1.0
# 		 mount.v.04 	 0.0 		 0.0 		 1.0
# 		 hop_on.v.01 	 0.0 		 0.0 		 1.0
# 		 climb.v.01 	 0.0 		 0.0 		 1.0
# 		 mount.v.07 	 0.0 		 0.0 		 1.0
# 		 ride.v.14 	 0.0 		 0.0 		 1.0
# 	 sentiment score of 'mount': 0.0
#
# 	target word: deal
# 		synset name	positive 	negative 	objective
# 		 deal.n.01 	 0.0 		 0.0 		 1.0
# 		 bargain.n.01 	 0.0 		 0.0 		 1.0
# 		 batch.n.02 	 0.0 		 0.0 		 1.0
# 		 deal.n.04 	 0.0 		 0.0 		 1.0
# 		 softwood.n.01 	 0.0 		 0.0 		 1.0
# 		 hand.n.06 	 0.0 		 0.0 		 1.0
# 		 deal.n.07 	 0.0 		 0.0 		 1.0
# 		 deal.n.08 	 0.0 		 0.0 		 1.0
# 		 deal.n.09 	 0.0 		 0.0 		 1.0
# 		 cover.v.05 	 0.0 		 0.0 		 1.0
# 		 consider.v.03 	 0.0 		 0.0 		 1.0
# 		 deal.v.03 	 0.0 		 0.0 		 1.0
# 		 cope.v.01 	 0.0 		 0.0 		 1.0
# 		 distribute.v.01 	 0.0 		 0.0 		 1.0
# 		 deal.v.06 	 0.0 		 0.0 		 1.0
# 		 manage.v.02 	 0.0 		 0.0 		 1.0
# 		 deal.v.08 	 0.0 		 0.0 		 1.0
# 		 deal.v.09 	 0.0 		 0.0 		 1.0
# 		 conduct.v.01 	 0.0 		 0.0 		 1.0
# 		 share.v.04 	 0.0 		 0.0 		 1.0
# 		 deal.v.12 	 0.0 		 0.0 		 1.0
# 		 deal.v.13 	 0.0 		 0.0 		 1.0
# 	 sentiment score of 'deal': 0.0
#
# 	target word: populace
# 		synset name	positive 	negative 	objective
# 		 populace.n.01 	 0.0 		 0.0 		 1.0
# 	 sentiment score of 'populace': 0.0
#
# 	target word: slightly
# 		synset name	positive 	negative 	objective
# 		 slightly.r.01 	 0.0 		 0.0 		 1.0
# 		 slenderly.r.01 	 0.25 		 0.0 		 0.75
# 	 sentiment score of 'slightly': 0.0
#
# used neighbor words 	 ['establish', 'busy', 'overflow', 'destroy']
# sentiment score of each neighbor word 	 [0.5, -0.3125, -0.5, -0.5]
# final sentiment score of 'paris': 	 -0.203125

# %%
print("\n")
print("#"*60)
query = 'london'
results = location_sentiment_analysis(query=query, w2v_model=w2v_model, num_k=20, obj_threshold=0.5)
query, neighbor_words, used_neighbor_list, sentiment_score = results

print()
scatterplot(w2v_model, query, neighbor_words, used_neighbor_list, other_words_list=['paris', 'england', 'france'], method='tsne')
# Out:
# ############################################################
# Query:  london
# K-neigbor words:  ['tellson', 'mail', 'busy', 'partner', 'worthy', 'orphan', 'plane', 'elderly', 'blind', 'arrive', 'seventy', 'bank', 'lodging', 'year', 'tellson_s', 'harness', 'description', 'hay', 'occupation', 'peace']
# K-neigbor distances:  [0.2956874370574951, 0.25125938653945923, 0.24844637513160706, 0.24216477572917938, 0.2364470660686493, 0.21845492720603943, 0.21606044471263885, 0.20789942145347595, 0.2076665163040161, 0.20607450604438782, 0.20242592692375183, 0.20105814933776855, 0.19967180490493774, 0.19859161972999573, 0.19798478484153748, 0.19285878539085388, 0.19185477495193481, 0.18657512962818146, 0.18314382433891296, 0.18270191550254822]
#
# 	target word: tellson
# 		synset name	positive 	negative 	objective
# 	 sentiment score of 'tellson': 0.0
#
# 	target word: mail
# 		synset name	positive 	negative 	objective
# 		 mail.n.01 	 0.0 		 0.0 		 1.0
# 		 mail.n.02 	 0.0 		 0.0 		 1.0
# 		 mail.n.03 	 0.0 		 0.0 		 1.0
# 		 mail.n.04 	 0.0 		 0.0 		 1.0
# 		 chain_mail.n.01 	 0.0 		 0.0 		 1.0
# 		 mail.v.01 	 0.0 		 0.0 		 1.0
# 		 mail.v.02 	 0.0 		 0.0 		 1.0
# 	 sentiment score of 'mail': 0.0
#
# 	target word: busy
# 		synset name	positive 	negative 	objective
# 		 busy.v.01 	 0.375 		 0.0 		 0.625
# 		 busy.a.01 	 0.375 		 0.0 		 0.625
# 		 busy.s.02 	 0.25 		 0.0 		 0.75
# 		 interfering.s.01 	 0.0 		 0.75 		 0.25 	(used for SA)
# 		 busy.s.04 	 0.375 		 0.25 		 0.375 	(used for SA)
# 		 busy.s.05 	 0.0 		 0.0 		 1.0
# 	 sentiment score of 'busy': -0.3125
#
# 	target word: partner
# 		synset name	positive 	negative 	objective
# 		 spouse.n.01 	 0.0 		 0.0 		 1.0
# 		 collaborator.n.03 	 0.0 		 0.0 		 1.0
# 		 partner.n.03 	 0.0 		 0.0 		 1.0
# 		 partner.v.01 	 0.0 		 0.0 		 1.0
# 		 partner.v.02 	 0.0 		 0.0 		 1.0
# 	 sentiment score of 'partner': 0.0
#
# 	target word: worthy
# 		synset name	positive 	negative 	objective
# 		 worthy.n.01 	 0.5 		 0.0 		 0.5 	(used for SA)
# 		 worthy.a.01 	 0.875 		 0.0 		 0.125 	(used for SA)
# 		 desirable.s.02 	 0.5 		 0.0 		 0.5 	(used for SA)
# 		 worthy.s.03 	 0.875 		 0.0 		 0.125 	(used for SA)
# 	 sentiment score of 'worthy': 0.6875
#
# 	target word: orphan
# 		synset name	positive 	negative 	objective
# 		 orphan.n.01 	 0.0 		 0.0 		 1.0
# 		 orphan.n.02 	 0.0 		 0.0 		 1.0
# 		 orphan.n.03 	 0.0 		 0.0 		 1.0
# 		 orphan.n.04 	 0.0 		 0.125 		 0.875
# 		 orphan.v.01 	 0.0 		 0.0 		 1.0
# 	 sentiment score of 'orphan': 0.0
#
# 	target word: plane
# 		synset name	positive 	negative 	objective
# 		 airplane.n.01 	 0.0 		 0.0 		 1.0
# 		 plane.n.02 	 0.0 		 0.0 		 1.0
# 		 plane.n.03 	 0.0 		 0.0 		 1.0
# 		 plane.n.04 	 0.0 		 0.0 		 1.0
# 		 plane.n.05 	 0.0 		 0.0 		 1.0
# 		 plane.v.01 	 0.0 		 0.0 		 1.0
# 		 plane.v.02 	 0.0 		 0.0 		 1.0
# 		 plane.v.03 	 0.0 		 0.0 		 1.0
# 		 flat.s.01 	 0.375 		 0.25 		 0.375 	(used for SA)
# 	 sentiment score of 'plane': 0.125
#
# 	target word: elderly
# 		synset name	positive 	negative 	objective
# 		 aged.n.01 	 0.0 		 0.0 		 1.0
# 		 aged.s.01 	 0.5 		 0.0 		 0.5 	(used for SA)
# 	 sentiment score of 'elderly': 0.5
#
# 	target word: blind
# 		synset name	positive 	negative 	objective
# 		 blind.n.01 	 0.0 		 0.0 		 1.0
# 		 blind.n.02 	 0.0 		 0.0 		 1.0
# 		 blind.n.03 	 0.0 		 0.0 		 1.0
# 		 subterfuge.n.01 	 0.0 		 0.25 		 0.75
# 		 blind.v.01 	 0.0 		 0.375 		 0.625
# 		 blind.v.02 	 0.0 		 0.375 		 0.625
# 		 blind.v.03 	 0.0 		 0.125 		 0.875
# 		 blind.a.01 	 0.0 		 0.0 		 1.0
# 		 blind.s.02 	 0.0 		 0.75 		 0.25 	(used for SA)
# 		 blind.s.03 	 0.0 		 0.5 		 0.5 	(used for SA)
# 	 sentiment score of 'blind': -0.625
#
# 	target word: arrive
# 		synset name	positive 	negative 	objective
# 		 arrive.v.01 	 0.0 		 0.0 		 1.0
# 		 arrive.v.02 	 0.0 		 0.0 		 1.0
# 	 sentiment score of 'arrive': 0.0
#
# 	target word: seventy
# 		synset name	positive 	negative 	objective
# 		 seventy.n.01 	 0.0 		 0.0 		 1.0
# 		 seventy.s.01 	 0.0 		 0.0 		 1.0
# 	 sentiment score of 'seventy': 0.0
#
# 	target word: bank
# 		synset name	positive 	negative 	objective
# 		 bank.n.01 	 0.0 		 0.0 		 1.0
# 		 depository_financial_institution.n.01 	 0.0 		 0.0 		 1.0
# 		 bank.n.03 	 0.0 		 0.0 		 1.0
# 		 bank.n.04 	 0.0 		 0.0 		 1.0
# 		 bank.n.05 	 0.0 		 0.0 		 1.0
# 		 bank.n.06 	 0.0 		 0.0 		 1.0
# 		 bank.n.07 	 0.0 		 0.0 		 1.0
# 		 savings_bank.n.02 	 0.0 		 0.0 		 1.0
# 		 bank.n.09 	 0.0 		 0.0 		 1.0
# 		 bank.n.10 	 0.0 		 0.0 		 1.0
# 		 bank.v.01 	 0.0 		 0.0 		 1.0
# 		 bank.v.02 	 0.0 		 0.0 		 1.0
# 		 bank.v.03 	 0.0 		 0.0 		 1.0
# 		 bank.v.04 	 0.0 		 0.0 		 1.0
# 		 bank.v.05 	 0.0 		 0.0 		 1.0
# 		 deposit.v.02 	 0.0 		 0.0 		 1.0
# 		 bank.v.07 	 0.0 		 0.0 		 1.0
# 		 trust.v.01 	 0.375 		 0.0 		 0.625
# 	 sentiment score of 'bank': 0.0
#
# 	target word: lodging
# 		synset name	positive 	negative 	objective
# 		 housing.n.01 	 0.0 		 0.0 		 1.0
# 		 lodgment.n.02 	 0.125 		 0.125 		 0.75
# 		 lodging.n.03 	 0.0 		 0.0 		 1.0
# 		 lodge.v.01 	 0.0 		 0.0 		 1.0
# 		 lodge.v.02 	 0.0 		 0.0 		 1.0
# 		 charge.v.06 	 0.0 		 0.0 		 1.0
# 		 lodge.v.04 	 0.0 		 0.0 		 1.0
# 	 sentiment score of 'lodging': 0.0
#
# 	target word: year
# 		synset name	positive 	negative 	objective
# 		 year.n.01 	 0.0 		 0.0 		 1.0
# 		 year.n.02 	 0.0 		 0.0 		 1.0
# 		 year.n.03 	 0.0 		 0.0 		 1.0
# 		 class.n.06 	 0.0 		 0.0 		 1.0
# 	 sentiment score of 'year': 0.0
#
# 	target word: tellson_s
# 		synset name	positive 	negative 	objective
# 	 sentiment score of 'tellson_s': 0.0
#
# 	target word: harness
# 		synset name	positive 	negative 	objective
# 		 harness.n.01 	 0.0 		 0.0 		 1.0
# 		 harness.n.02 	 0.0 		 0.0 		 1.0
# 		 harness.v.01 	 0.0 		 0.0 		 1.0
# 		 harness.v.02 	 0.125 		 0.0 		 0.875
# 		 harness.v.03 	 0.0 		 0.0 		 1.0
# 		 rule.v.07 	 0.0 		 0.0 		 1.0
# 	 sentiment score of 'harness': 0.0
#
# 	target word: description
# 		synset name	positive 	negative 	objective
# 		 description.n.01 	 0.0 		 0.0 		 1.0
# 		 description.n.02 	 0.0 		 0.0 		 1.0
# 		 description.n.03 	 0.0 		 0.125 		 0.875
# 	 sentiment score of 'description': 0.0
#
# 	target word: hay
# 		synset name	positive 	negative 	objective
# 		 hay.n.01 	 0.0 		 0.0 		 1.0
# 		 hay.v.01 	 0.0 		 0.0 		 1.0
# 	 sentiment score of 'hay': 0.0
#
# 	target word: occupation
# 		synset name	positive 	negative 	objective
# 		 occupation.n.01 	 0.0 		 0.0 		 1.0
# 		 occupation.n.02 	 0.0 		 0.0 		 1.0
# 		 occupation.n.03 	 0.0 		 0.0 		 1.0
# 		 occupation.n.04 	 0.0 		 0.0 		 1.0
# 		 occupation.n.05 	 0.0 		 0.0 		 1.0
# 	 sentiment score of 'occupation': 0.0
#
# 	target word: peace
# 		synset name	positive 	negative 	objective
# 		 peace.n.01 	 0.125 		 0.0 		 0.875
# 		 peace.n.02 	 0.25 		 0.0 		 0.75
# 		 peace.n.03 	 0.125 		 0.5 		 0.375 	(used for SA)
# 		 peace.n.04 	 0.0 		 0.0 		 1.0
# 		 peace.n.05 	 0.0 		 0.0 		 1.0
# 	 sentiment score of 'peace': -0.375
#
# used neighbor words 	 ['busy', 'worthy', 'plane', 'elderly', 'blind', 'peace']
# sentiment score of each neighbor word 	 [-0.3125, 0.6875, 0.125, 0.5, -0.625, -0.375]
# final sentiment score of 'london': 	 0.0

# %%
print("\n")
print("#"*60)
query = 'paris'
results = location_sentiment_analysis(query=query, w2v_model=w2v_model, num_k=20, obj_threshold=0.5)
query, neighbor_words, used_neighbor_list, sentiment_score = results

print()
scatterplot(w2v_model, query, neighbor_words, used_neighbor_list, other_words_list=['london', 'england', 'france'], method='tsne')
# Out:
# ############################################################
# Query:  paris
# K-neigbor words:  ['journey', 'establish', 'busy', 'bank', 'country', 'overflow', 'destroy', 'mode', 'beauvais', 'despatch', 'communicate', 'day', 'keeper', 'shilling', 'road', 'travel', 'mount', 'deal', 'populace', 'slightly']
# K-neigbor distances:  [0.2842642366886139, 0.23648369312286377, 0.21542930603027344, 0.21482771635055542, 0.21150873601436615, 0.20536592602729797, 0.1969098150730133, 0.1966996192932129, 0.19505669176578522, 0.19394749402999878, 0.18605686724185944, 0.18340164422988892, 0.1772938221693039, 0.17596665024757385, 0.1745319813489914, 0.17398419976234436, 0.1736697405576706, 0.1722383052110672, 0.16972346603870392, 0.1663377285003662]
#
# 	target word: journey
# 		synset name	positive 	negative 	objective
# 		 journey.n.01 	 0.0 		 0.0 		 1.0
# 		 travel.v.02 	 0.0 		 0.0 		 1.0
# 		 travel.v.04 	 0.0 		 0.0 		 1.0
# 	 sentiment score of 'journey': 0.0
#
# 	target word: establish
# 		synset name	positive 	negative 	objective
# 		 establish.v.01 	 0.0 		 0.0 		 1.0
# 		 establish.v.02 	 0.0 		 0.0 		 1.0
# 		 prove.v.02 	 0.5 		 0.0 		 0.5 	(used for SA)
# 		 lay_down.v.01 	 0.0 		 0.0 		 1.0
# 		 establish.v.05 	 0.0 		 0.0 		 1.0
# 		 install.v.03 	 0.0 		 0.0 		 1.0
# 		 build.v.03 	 0.0 		 0.0 		 1.0
# 		 establish.v.08 	 0.0 		 0.0 		 1.0
# 	 sentiment score of 'establish': 0.5
#
# 	target word: busy
# 		synset name	positive 	negative 	objective
# 		 busy.v.01 	 0.375 		 0.0 		 0.625
# 		 busy.a.01 	 0.375 		 0.0 		 0.625
# 		 busy.s.02 	 0.25 		 0.0 		 0.75
# 		 interfering.s.01 	 0.0 		 0.75 		 0.25 	(used for SA)
# 		 busy.s.04 	 0.375 		 0.25 		 0.375 	(used for SA)
# 		 busy.s.05 	 0.0 		 0.0 		 1.0
# 	 sentiment score of 'busy': -0.3125
#
# 	target word: bank
# 		synset name	positive 	negative 	objective
# 		 bank.n.01 	 0.0 		 0.0 		 1.0
# 		 depository_financial_institution.n.01 	 0.0 		 0.0 		 1.0
# 		 bank.n.03 	 0.0 		 0.0 		 1.0
# 		 bank.n.04 	 0.0 		 0.0 		 1.0
# 		 bank.n.05 	 0.0 		 0.0 		 1.0
# 		 bank.n.06 	 0.0 		 0.0 		 1.0
# 		 bank.n.07 	 0.0 		 0.0 		 1.0
# 		 savings_bank.n.02 	 0.0 		 0.0 		 1.0
# 		 bank.n.09 	 0.0 		 0.0 		 1.0
# 		 bank.n.10 	 0.0 		 0.0 		 1.0
# 		 bank.v.01 	 0.0 		 0.0 		 1.0
# 		 bank.v.02 	 0.0 		 0.0 		 1.0
# 		 bank.v.03 	 0.0 		 0.0 		 1.0
# 		 bank.v.04 	 0.0 		 0.0 		 1.0
# 		 bank.v.05 	 0.0 		 0.0 		 1.0
# 		 deposit.v.02 	 0.0 		 0.0 		 1.0
# 		 bank.v.07 	 0.0 		 0.0 		 1.0
# 		 trust.v.01 	 0.375 		 0.0 		 0.625
# 	 sentiment score of 'bank': 0.0
#
# 	target word: country
# 		synset name	positive 	negative 	objective
# 		 state.n.04 	 0.0 		 0.0 		 1.0
# 		 country.n.02 	 0.0 		 0.0 		 1.0
# 		 nation.n.02 	 0.0 		 0.0 		 1.0
# 		 country.n.04 	 0.0 		 0.0 		 1.0
# 		 area.n.01 	 0.0 		 0.0 		 1.0
# 	 sentiment score of 'country': 0.0
#
# 	target word: overflow
# 		synset name	positive 	negative 	objective
# 		 flood.n.04 	 0.0 		 0.0 		 1.0
# 		 overflow.n.02 	 0.0 		 0.0 		 1.0
# 		 overflow.v.01 	 0.0 		 0.0 		 1.0
# 		 bubble_over.v.01 	 0.25 		 0.75 		 0.0 	(used for SA)
# 	 sentiment score of 'overflow': -0.5
#
# 	target word: destroy
# 		synset name	positive 	negative 	objective
# 		 destroy.v.01 	 0.0 		 0.0 		 1.0
# 		 destroy.v.02 	 0.0 		 0.5 		 0.5 	(used for SA)
# 		 demolish.v.03 	 0.125 		 0.0 		 0.875
# 		 destroy.v.04 	 0.0 		 0.25 		 0.75
# 	 sentiment score of 'destroy': -0.5
#
# 	target word: mode
# 		synset name	positive 	negative 	objective
# 		 manner.n.01 	 0.0 		 0.0 		 1.0
# 		 mode.n.02 	 0.0 		 0.0 		 1.0
# 		 modality.n.01 	 0.0 		 0.0 		 1.0
# 		 mood.n.03 	 0.0 		 0.0 		 1.0
# 		 mode.n.05 	 0.0 		 0.0 		 1.0
# 		 mode.n.06 	 0.0 		 0.0 		 1.0
# 	 sentiment score of 'mode': 0.0
#
# 	target word: beauvais
# 		synset name	positive 	negative 	objective
# 	 sentiment score of 'beauvais': 0.0
#
# 	target word: despatch
# 		synset name	positive 	negative 	objective
# 		 dispatch.n.01 	 0.0 		 0.0 		 1.0
# 		 dispatch.n.03 	 0.0 		 0.0 		 1.0
# 		 dispatch.n.04 	 0.0 		 0.0 		 1.0
# 		 dispatch.n.02 	 0.0 		 0.0 		 1.0
# 		 dispatch.v.01 	 0.0 		 0.0 		 1.0
# 	 sentiment score of 'despatch': 0.0
#
# 	target word: communicate
# 		synset name	positive 	negative 	objective
# 		 communicate.v.01 	 0.0 		 0.0 		 1.0
# 		 communicate.v.02 	 0.0 		 0.125 		 0.875
# 		 convey.v.03 	 0.0 		 0.0 		 1.0
# 		 communicate.v.04 	 0.0 		 0.0 		 1.0
# 		 communicate.v.05 	 0.0 		 0.0 		 1.0
# 		 communicate.v.06 	 0.0 		 0.0 		 1.0
# 		 commune.v.02 	 0.0 		 0.0 		 1.0
# 	 sentiment score of 'communicate': 0.0
#
# 	target word: day
# 		synset name	positive 	negative 	objective
# 		 day.n.01 	 0.0 		 0.0 		 1.0
# 		 day.n.02 	 0.125 		 0.0 		 0.875
# 		 day.n.03 	 0.0 		 0.0 		 1.0
# 		 day.n.04 	 0.0 		 0.0 		 1.0
# 		 day.n.05 	 0.0 		 0.0 		 1.0
# 		 day.n.06 	 0.125 		 0.0 		 0.875
# 		 day.n.07 	 0.0 		 0.0 		 1.0
# 		 sidereal_day.n.01 	 0.0 		 0.0 		 1.0
# 		 day.n.09 	 0.25 		 0.0 		 0.75
# 		 day.n.10 	 0.0 		 0.0 		 1.0
# 	 sentiment score of 'day': 0.0
#
# 	target word: keeper
# 		synset name	positive 	negative 	objective
# 		 keeper.n.01 	 0.0 		 0.0 		 1.0
# 		 custodian.n.01 	 0.0 		 0.0 		 1.0
# 	 sentiment score of 'keeper': 0.0
#
# 	target word: shilling
# 		synset name	positive 	negative 	objective
# 		 ugandan_shilling.n.01 	 0.0 		 0.0 		 1.0
# 		 tanzanian_shilling.n.01 	 0.0 		 0.0 		 1.0
# 		 somalian_shilling.n.01 	 0.0 		 0.0 		 1.0
# 		 kenyan_shilling.n.01 	 0.0 		 0.0 		 1.0
# 		 british_shilling.n.01 	 0.0 		 0.0 		 1.0
# 		 shilling.n.06 	 0.0 		 0.0 		 1.0
# 		 shill.v.01 	 0.0 		 0.0 		 1.0
# 	 sentiment score of 'shilling': 0.0
#
# 	target word: road
# 		synset name	positive 	negative 	objective
# 		 road.n.01 	 0.0 		 0.0 		 1.0
# 		 road.n.02 	 0.0 		 0.0 		 1.0
# 	 sentiment score of 'road': 0.0
#
# 	target word: travel
# 		synset name	positive 	negative 	objective
# 		 travel.n.01 	 0.0 		 0.0 		 1.0
# 		 change_of_location.n.01 	 0.0 		 0.0 		 1.0
# 		 locomotion.n.02 	 0.0 		 0.0 		 1.0
# 		 travel.v.01 	 0.0 		 0.0 		 1.0
# 		 travel.v.02 	 0.0 		 0.0 		 1.0
# 		 travel.v.03 	 0.0 		 0.0 		 1.0
# 		 travel.v.04 	 0.0 		 0.0 		 1.0
# 		 travel.v.05 	 0.0 		 0.0 		 1.0
# 		 travel.v.06 	 0.0 		 0.0 		 1.0
# 	 sentiment score of 'travel': 0.0
#
# 	target word: mount
# 		synset name	positive 	negative 	objective
# 		 saddle_horse.n.01 	 0.0 		 0.0 		 1.0
# 		 climb.n.03 	 0.0 		 0.0 		 1.0
# 		 mountain.n.01 	 0.0 		 0.0 		 1.0
# 		 mount.n.04 	 0.0 		 0.0 		 1.0
# 		 backing.n.02 	 0.0 		 0.0 		 1.0
# 		 mount.v.01 	 0.0 		 0.0 		 1.0
# 		 wax.v.02 	 0.0 		 0.0 		 1.0
# 		 mount.v.03 	 0.0 		 0.0 		 1.0
# 		 mount.v.04 	 0.0 		 0.0 		 1.0
# 		 hop_on.v.01 	 0.0 		 0.0 		 1.0
# 		 climb.v.01 	 0.0 		 0.0 		 1.0
# 		 mount.v.07 	 0.0 		 0.0 		 1.0
# 		 ride.v.14 	 0.0 		 0.0 		 1.0
# 	 sentiment score of 'mount': 0.0
#
# 	target word: deal
# 		synset name	positive 	negative 	objective
# 		 deal.n.01 	 0.0 		 0.0 		 1.0
# 		 bargain.n.01 	 0.0 		 0.0 		 1.0
# 		 batch.n.02 	 0.0 		 0.0 		 1.0
# 		 deal.n.04 	 0.0 		 0.0 		 1.0
# 		 softwood.n.01 	 0.0 		 0.0 		 1.0
# 		 hand.n.06 	 0.0 		 0.0 		 1.0
# 		 deal.n.07 	 0.0 		 0.0 		 1.0
# 		 deal.n.08 	 0.0 		 0.0 		 1.0
# 		 deal.n.09 	 0.0 		 0.0 		 1.0
# 		 cover.v.05 	 0.0 		 0.0 		 1.0
# 		 consider.v.03 	 0.0 		 0.0 		 1.0
# 		 deal.v.03 	 0.0 		 0.0 		 1.0
# 		 cope.v.01 	 0.0 		 0.0 		 1.0
# 		 distribute.v.01 	 0.0 		 0.0 		 1.0
# 		 deal.v.06 	 0.0 		 0.0 		 1.0
# 		 manage.v.02 	 0.0 		 0.0 		 1.0
# 		 deal.v.08 	 0.0 		 0.0 		 1.0
# 		 deal.v.09 	 0.0 		 0.0 		 1.0
# 		 conduct.v.01 	 0.0 		 0.0 		 1.0
# 		 share.v.04 	 0.0 		 0.0 		 1.0
# 		 deal.v.12 	 0.0 		 0.0 		 1.0
# 		 deal.v.13 	 0.0 		 0.0 		 1.0
# 	 sentiment score of 'deal': 0.0
#
# 	target word: populace
# 		synset name	positive 	negative 	objective
# 		 populace.n.01 	 0.0 		 0.0 		 1.0
# 	 sentiment score of 'populace': 0.0
#
# 	target word: slightly
# 		synset name	positive 	negative 	objective
# 		 slightly.r.01 	 0.0 		 0.0 		 1.0
# 		 slenderly.r.01 	 0.25 		 0.0 		 0.75
# 	 sentiment score of 'slightly': 0.0
#
# used neighbor words 	 ['establish', 'busy', 'overflow', 'destroy']
# sentiment score of each neighbor word 	 [0.5, -0.3125, -0.5, -0.5]
# final sentiment score of 'paris': 	 -0.203125
